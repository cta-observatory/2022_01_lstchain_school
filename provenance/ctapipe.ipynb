# %% [markdown]
# # ctapipe provenance
#
# Let's run a ctapipe tool to generate provenance files. So we ask ctapipe which tools are available for us to use.

# %%
# !ctapipe-info --tools
# Out:
# *** ctapipe tools ***
#
# the following can be executed by typing ctapipe-<toolname>:
#
# INFO - NumExpr defaulting to 8 threads.
# INFO - Downloading http://cccta-dataserver.in2p3.fr/data/ctapipe-extra/v0.3.3/optics.fits.gz to /Users/jer/.cache/ctapipe/cccta-dataserver.in2p3.fr/data/ctapipe-extra/v0.3.3/optics.fits.gz
# INFO - Downloading http://cccta-dataserver.in2p3.fr/data/ctapipe-extra/v0.3.3/optics.fits to /Users/jer/.cache/ctapipe/cccta-dataserver.in2p3.fr/data/ctapipe-extra/v0.3.3/optics.fits
# INFO - Downloading http://cccta-dataserver.in2p3.fr/data/ctapipe-extra/v0.3.3/optics.ecsv to /Users/jer/.cache/ctapipe/cccta-dataserver.in2p3.fr/data/ctapipe-extra/v0.3.3/optics.ecsv
# ctapipe-camdemo                 -  Example tool, displaying fake events in a
#                                    camera.  the animation should remain
#                                    interactive, so try zooming in when it is
#                                    running.
#
# ctapipe-display-dl1             -  Calibrate dl0 data to dl1, and plot the
#                                    photoelectron images.
#
# ctapipe-display-imagesums       -  Select a group of similar telescopes (with
#                                    same camera type), Loop over events where
#                                    telescopes in the group participate, sum the
#                                    image from each telescope, and display it.
#
# ctapipe-display-integration     -  Calibrate dl0 data to dl1, and plot the
#                                    various camera images that characterise the
#                                    event and calibration. Also plot some
#                                    examples of waveforms with the integration
#                                    window.
#
# ctapipe-display-tel-events      -  Loops over events in a data file and displays
#                                    them, with optional image cleaning and hillas
#                                    parameter overlays.  Only events that contain
#                                    the specified telescope are read and
#                                    displayed. Other telescopes and events are
#                                    skipped over (EventIO data files have no
#                                    index table in them, so the events must be
#                                    read in sequence to find ones with the
#                                    appropriate telescope, therefore this is not
#                                    a fast operation)
#
# ctapipe-dump-instrument         -  Dump instrumental descriptions in a monte-
#                                    carlo (simtelarray) input file to FITS files
#                                    that can be loaded independently (e.g. with
#                                    CameraGeometry.from_table()).  The name of
#                                    the output files are automatically generated.
#
# ctapipe-dump-triggers           -  dump a table of the event times and trigger
#                                    patterns from a simtelarray input file.
#
# ctapipe-event-viewer            - [no documentation. Please add a docstring]
#
# ctapipe-info                    -  print information about ctapipe and its
#                                    command-line tools.
#
# ctapipe-merge                   -  Merge DL1-files from stage1-process tool
#
# ctapipe-reconstruct-muons       - [no documentation. Please add a docstring]
#
# ctapipe-stage1                  -  Generate DL1 (a or b) output files in HDF5
#                                    format from {R0,R1,DL0} inputs.

# %%
# !ctapipe-stage1 --help
# Out:
# Process data from lower-data levels up to DL1, including both image
# extraction and optinally image parameterization
#  This currently writes v1.1.0 DL1 data
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --write-images
#     store DL1/Event/Telescope images in output
#     Equivalent to: [--DL1Writer.write_images=True]
# --write-parameters
#     store DL1/Event/Telescope parameters in output
#     Equivalent to: [--DL1Writer.write_parameters=True]
# --write-index-tables
#     generate PyTables index tables for the parameter and image datasets
#     Equivalent to: [--DL1Writer.write_index_tables=True]
# --overwrite
#     Overwrite output file if it exists
#     Equivalent to: [--DL1Writer.overwrite=True]
# --progress
#     show a progress bar during event processing
#     Equivalent to: [--Stage1Tool.progress_bar=True]
# -q, --quiet
#     Disable console logging.
#     Equivalent to: [--Tool.quiet=True]
# --input=<Path>
#     Path to the input file containing events.
#     Default: None
#     Equivalent to: [--EventSource.input_url]
# --output=<Path>
#     DL1 output filename
#     Default: PosixPath('events.dl1.h5')
#     Equivalent to: [--DL1Writer.output_path]
# --allowed-tels=<set-item-1>...
#     list of allowed tel_ids, others will be ignored. If None, all telescopes in
#     the input stream will be included
#     Default: set()
#     Equivalent to: [--EventSource.allowed_tels]
# --max-events=<Int>
#     Maximum number of events that will be read from the file
#     Default: None
#     Equivalent to: [--EventSource.max_events]
# --image-cleaner-type=<CaselessStrEnum>
#     ImageCleaner to use.
#     Choices: any of ['TailcutsImageCleaner', 'MARSImageCleaner', 'FACTImageCleaner'] (case-insensitive)
#     Default: 'TailcutsImageCleaner'
#     Equivalent to: [--ImageProcessor.image_cleaner_type]
# --config=<Path>
#     name of a configuration file with parameters to load in addition to command-
#     line parameters
#     Default: None
#     Equivalent to: [--Tool.config_file]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Tool.log_level]
# -l, --log-file=<Path>
#     Filename for the log
#     Default: None
#     Equivalent to: [--Tool.log_file]
# --log-file-level=<Enum>
#     Logging Level for File Logging
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 'INFO'
#     Equivalent to: [--Tool.log_file_level]
#
# Examples
# --------
#
#     To process data with all default values:
#     > ctapipe-stage1 --input events.simtel.gz --output events.dl1.h5 --progress
#
#     Or use an external configuration file, where you can specify all options:
#     > ctapipe-stage1 --config stage1_config.json --progress
#
#     The config file should be in JSON or python format (see traitlets docs). For an
#     example, see ctapipe/examples/stage1_config.json in the main code repo.
#
# To see all available configurables, use `--help-all`.

# %% [markdown]
# Ok, let's copy a sample events file to this working directory to run the `ctapipe-stage1` tool and clean the folder of previous log files

# %%
from ctapipe import utils
import shutil

shutil.copy(utils.get_dataset_path("gamma_test.simtel.gz"), "gamma_test.simtel.gz")
# Out:
# 'gamma_test.simtel.gz'

# %%
# !rm *.log

# %% [markdown]
# Now we run `ctapipe-stage1` with the `--log-file` option

# %%
# !ctapipe-stage1 --input gamma_test.simtel.gz --progress --overwrite --log-file mylog.log
# Out:
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type LSTCam
#   warnings.warn(
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type NectarCam
#   warnings.warn(
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type CHEC
#   warnings.warn(
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type SCTCam
#   warnings.warn(
# 2022-01-17 13:46:21,296 WARNING [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_output_path): Overwriting /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# SimTelEventSource: 8ev [00:04,  3.87ev/s]2022-01-17 13:46:26,178 WARNING [ctapipe.ctapipe-stage1.SimTelEventSource] (simteleventsource._generator): EOFError reading from "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz". Might be truncated
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:353: UserWarning: EOFError reading from "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz". Might be truncated
#   warnings.warn(msg)
# SimTelEventSource: 9ev [00:04,  1.97ev/s]

# %% [markdown]
# A JSON formatted provenance file is produced with the name of the executed tool in the filename together with a classic timestamps log file

# %%
# !ls *.log
# Out:
# ctapipe-stage1.provenance.log mylog.log

# %%
# !head ctapipe-stage1.provenance.log
# Out:
# [
#    {
#       "activity_name": "ctapipe-stage1",
#       "activity_uuid": "491e433c-06d1-4199-b714-f81b93846076",
#       "start": {
#          "time_utc": "2022-01-17T12:46:20.036"
#       },
#       "stop": {
#          "time_utc": "2022-01-17T12:46:26.265"
#       },

# %%
# !cat mylog.log
# Out:
# 2022-01-17 13:46:20,035 INFO [ctapipe.ctapipe-stage1] (tool.initialize): ctapipe version 0.11.0
# 2022-01-17 13:46:20,035 INFO [ctapipe.ctapipe-stage1] (tool.run): Starting: ctapipe-stage1
# 2022-01-17 13:46:20,060 INFO [ctapipe.ctapipe-stage1.SimTelEventSource] (eventsource.__init__): INPUT PATH = /Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz
# 2022-01-17 13:46:21,296 WARNING [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_output_path): Overwriting /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# 2022-01-17 13:46:21,562 INFO [ctapipe.ctapipe-stage1] (subarray.info): Subarray : MonteCarloArray
# 2022-01-17 13:46:21,562 INFO [ctapipe.ctapipe-stage1] (subarray.info): Num Tels : 126
# 2022-01-17 13:46:21,563 INFO [ctapipe.ctapipe-stage1] (subarray.info): Footprint: 7.32 km2
# 2022-01-17 13:46:21,563 INFO [ctapipe.ctapipe-stage1] (subarray.info):
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):        Type       Count Tel IDs
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info): ----------------- ----- -------
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):    SST_ASTRI_CHEC    72 29-100
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):    MST_SCT_SCTCam    26 101-126
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info): MST_MST_NectarCam    24 5-28
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):    LST_LST_LSTCam     4 1-4
# 2022-01-17 13:46:26,178 WARNING [ctapipe.ctapipe-stage1.SimTelEventSource] (simteleventsource._generator): EOFError reading from "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz". Might be truncated
# 2022-01-17 13:46:26,181 INFO [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer.finish): Finishing DL1 output
# 2022-01-17 13:46:26,264 INFO [ctapipe.ctapipe-stage1] (tool.run): Finished: ctapipe-stage1
# 2022-01-17 13:46:26,265 INFO [ctapipe.ctapipe-stage1] (tool.write_provenance): Output: /Users/jer/Desktop/curso/notebooks/events.dl1.h5

# %% [markdown]
# Ok, now let's load the content of the provenance file into a Python object to better explore it

# %%
import json
with open('ctapipe-stage1.provenance.log') as json_file:
    provdata = json.load(json_file)

# %%
provdata
# Out:
# [{'activity_name': 'ctapipe-stage1',
#   'activity_uuid': '491e433c-06d1-4199-b714-f81b93846076',
#   'start': {'time_utc': '2022-01-17T12:46:20.036'},
#   'stop': {'time_utc': '2022-01-17T12:46:26.265'},
#   'system': {'ctapipe_version': '0.11.0',
#    'ctapipe_resources_version': 'not installed',
#    'eventio_version': '1.5.1.post1',
#    'ctapipe_svc_path': '/Users/jer/git/cta-observatory/ctapipe-extra/ctapipe_resources',
#    'executable': '/opt/miniconda3/envs/lst-school-2022-01/bin/python',
#    'platform': {'architecture_bits': '64bit',
#     'architecture_linkage': '',
#     'machine': 'x86_64',
#     'processor': 'i386',
#     'node': 'Joses-MacBook-Pro.local',
#     'version': 'Darwin Kernel Version 21.2.0: Sun Nov 28 20:28:54 PST 2021; root:xnu-8019.61.5~1/RELEASE_X86_64',
#     'system': 'Darwin',
#     'release': '21.2.0',
#     'libcver': ['', ''],
#     'num_cpus': 8,
#     'boot_time': '2021-12-14T21:43:28.000'},
#    'python': {'version_string': '3.8.12 | packaged by conda-forge | (default, Oct 12 2021, 21:50:56) \n[Clang 11.1.0 ]',
#     'version': ['3', '8', '12'],
#     'compiler': 'Clang 11.1.0 ',
#     'implementation': 'CPython',
#     'packages': [{'name': 'Babel',
#       'version': '2.9.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'Jinja2',
#       'version': '3.0.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'MarkupSafe',
#       'version': '2.0.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'Pillow',
#       'version': '8.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'PyQt5',
#       'version': '5.12.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'PyQt5-sip',
#       'version': '4.19.18',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'PyQtChart',
#       'version': '5.12',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'PyQtWebEngine',
#       'version': '5.12.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'PySocks',
#       'version': '1.7.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'PyYAML',
#       'version': '6.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'Pygments',
#       'version': '2.11.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'QtPy',
#       'version': '2.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'Send2Trash',
#       'version': '1.8.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'Sphinx',
#       'version': '4.3.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ViTables',
#       'version': '3.0.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'alabaster',
#       'version': '0.7.12',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'anyio',
#       'version': '2.2.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'appnope',
#       'version': '0.1.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'argon2-cffi',
#       'version': '21.3.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'argon2-cffi-bindings',
#       'version': '21.2.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'astropy',
#       'version': '4.3.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'asttokens',
#       'version': '2.0.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'attrs',
#       'version': '21.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'backcall',
#       'version': '0.2.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'backports.functools-lru-cache',
#       'version': '1.6.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'black',
#       'version': '21.12b0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'bleach',
#       'version': '4.1.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'bokeh',
#       'version': '1.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'brotlipy',
#       'version': '0.7.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'cached-property',
#       'version': '1.5.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'certifi',
#       'version': '2021.10.8',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'cffi',
#       'version': '1.15.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'charset-normalizer',
#       'version': '2.0.10',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'click',
#       'version': '8.0.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'colorama',
#       'version': '0.4.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'commonmark',
#       'version': '0.9.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'corsikaio',
#       'version': '0.2.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'coverage',
#       'version': '6.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'cryptography',
#       'version': '36.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ctapipe',
#       'version': '0.11.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ctapipe-io-lst',
#       'version': '0.13.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ctaplot',
#       'version': '0.5.6',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'cycler',
#       'version': '0.11.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'dataclasses',
#       'version': '0.8',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'debugpy',
#       'version': '1.5.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'decorator',
#       'version': '5.1.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'defusedxml',
#       'version': '0.7.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'docutils',
#       'version': '0.17.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'entrypoints',
#       'version': '0.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'eventio',
#       'version': '1.5.1.post1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'executing',
#       'version': '0.8.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'flit-core',
#       'version': '3.6.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'future',
#       'version': '0.18.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'gammapy',
#       'version': '0.18.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'h5py',
#       'version': '3.6.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'hypothesis',
#       'version': '6.35.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'idna',
#       'version': '3.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'imagesize',
#       'version': '1.3.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'iminuit',
#       'version': '1.5.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'importlib-metadata',
#       'version': '4.10.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'importlib-resources',
#       'version': '5.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'iniconfig',
#       'version': '1.1.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ipykernel',
#       'version': '6.0.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ipympl',
#       'version': '0.8.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ipython',
#       'version': '8.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ipython-genutils',
#       'version': '0.2.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ipywidgets',
#       'version': '7.6.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jedi',
#       'version': '0.18.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'joblib',
#       'version': '1.1.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'json5',
#       'version': '0.9.6',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jsonschema',
#       'version': '4.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyter',
#       'version': '1.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyter-client',
#       'version': '7.1.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyter-console',
#       'version': '6.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyter-core',
#       'version': '4.9.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyter-server',
#       'version': '1.4.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyterlab',
#       'version': '3.2.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyterlab-pygments',
#       'version': '0.1.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyterlab-server',
#       'version': '2.10.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'jupyterlab-widgets',
#       'version': '1.0.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'kiwisolver',
#       'version': '1.3.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'llvmlite', 'version': '0.38.0', 'path': None},
#      {'name': 'lstchain',
#       'version': '0.8.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'matplotlib',
#       'version': '3.4.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'matplotlib-inline',
#       'version': '0.1.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'mistune',
#       'version': '0.8.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'mock',
#       'version': '4.0.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'mypy-extensions',
#       'version': '0.4.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'nbclassic',
#       'version': '0.2.6',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'nbclient',
#       'version': '0.5.10',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'nbconvert',
#       'version': '6.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'nbformat',
#       'version': '5.1.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'nbsphinx',
#       'version': '0.8.8',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'nest-asyncio',
#       'version': '1.5.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'notebook',
#       'version': '6.4.7',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'numba',
#       'version': '0.55.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'numexpr',
#       'version': '2.8.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'numpy',
#       'version': '1.21.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'numpydoc',
#       'version': '1.1.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'olefile',
#       'version': '0.46',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'packaging',
#       'version': '21.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pandas',
#       'version': '1.3.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pandocfilters',
#       'version': '1.5.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'parso',
#       'version': '0.8.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pathspec',
#       'version': '0.9.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'patsy',
#       'version': '0.5.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pexpect',
#       'version': '4.8.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pickleshare',
#       'version': '0.7.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pip',
#       'version': '21.3.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'platformdirs',
#       'version': '2.3.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pluggy',
#       'version': '1.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'prometheus-client',
#       'version': '0.12.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'prompt-toolkit',
#       'version': '3.0.24',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'protobuf',
#       'version': '3.19.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'protozfits',
#       'version': '2.0.1.post1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'psutil',
#       'version': '5.9.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'ptyprocess',
#       'version': '0.7.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pure-eval',
#       'version': '0.2.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'py',
#       'version': '1.11.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pyOpenSSL',
#       'version': '21.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pycparser',
#       'version': '2.21',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pydantic',
#       'version': '1.9.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pyerfa',
#       'version': '2.0.0.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pyirf',
#       'version': '0.5.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pymongo',
#       'version': '4.0.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pyparsing',
#       'version': '2.4.7',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pyrsistent',
#       'version': '0.18.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest',
#       'version': '6.2.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-arraydiff',
#       'version': '0.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-astropy',
#       'version': '0.9.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-astropy-header',
#       'version': '0.1.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-cov',
#       'version': '3.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-doctestplus',
#       'version': '0.11.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-filter-subpackage',
#       'version': '0.1.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-mock',
#       'version': '3.6.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-openfiles',
#       'version': '0.5.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytest-remotedata',
#       'version': '0.3.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'python-dateutil',
#       'version': '2.8.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pytz',
#       'version': '2021.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'pyzmq',
#       'version': '22.3.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'qtconsole',
#       'version': '5.2.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'regions',
#       'version': '0.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'requests',
#       'version': '2.27.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'scikit-learn',
#       'version': '1.0.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'scipy',
#       'version': '1.7.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'seaborn',
#       'version': '0.11.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'setuptools',
#       'version': '59.7.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'setuptools-scm',
#       'version': '6.3.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'six',
#       'version': '1.16.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sniffio',
#       'version': '1.2.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'snowballstemmer',
#       'version': '2.2.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sortedcontainers',
#       'version': '2.4.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinx-argparse',
#       'version': '0.3.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinx-automodapi',
#       'version': '0.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinx-rtd-theme',
#       'version': '1.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinxcontrib-applehelp',
#       'version': '1.0.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinxcontrib-devhelp',
#       'version': '1.0.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinxcontrib-htmlhelp',
#       'version': '2.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinxcontrib-jsmath',
#       'version': '1.0.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinxcontrib-qthelp',
#       'version': '1.0.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'sphinxcontrib-serializinghtml',
#       'version': '1.1.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'stack-data',
#       'version': '0.1.4',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'statsmodels',
#       'version': '0.13.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'tables',
#       'version': '3.6.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'terminado',
#       'version': '0.12.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'testpath',
#       'version': '0.5.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'threadpoolctl',
#       'version': '3.0.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'toml',
#       'version': '0.10.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'tomli',
#       'version': '1.2.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'tornado',
#       'version': '6.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'tqdm',
#       'version': '4.62.3',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'traitlets',
#       'version': '5.0.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'typed-ast',
#       'version': '1.5.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'typing-extensions',
#       'version': '4.0.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'urllib3',
#       'version': '1.26.8',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'wcwidth',
#       'version': '0.2.5',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'webencodings',
#       'version': '0.5.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'wheel',
#       'version': '0.37.1',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'widgetsnbextension',
#       'version': '3.5.2',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'zipp',
#       'version': '3.7.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#      {'name': 'zstandard',
#       'version': '0.16.0',
#       'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'}]},
#    'environment': {'CONDA_DEFAULT_ENV': 'lst-school-2022-01',
#     'CONDA_PREFIX': '/opt/miniconda3/envs/lst-school-2022-01',
#     'CONDA_PYTHON_EXE': '/opt/miniconda3/bin/python',
#     'CONDA_EXE': '/opt/miniconda3/bin/conda',
#     'CONDA_PROMPT_MODIFIER': '(lst-school-2022-01) ',
#     'CONDA_SHLVL': '2',
#     'PATH': '/Users/jer/.rbenv/shims:/opt/miniconda3/envs/lst-school-2022-01/bin:/opt/miniconda3/condabin:/Users/jer/root/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin:/Library/TeX/texbin:/opt/X11/bin',
#     'LD_LIBRARY_PATH': '/Users/jer/root/lib',
#     'DYLD_LIBRARY_PATH': None,
#     'USER': 'jer',
#     'HOME': '/Users/jer',
#     'SHELL': '/bin/zsh'},
#    'arguments': ['/opt/miniconda3/envs/lst-school-2022-01/bin/ctapipe-stage1',
#     '--input',
#     'gamma_test.simtel.gz',
#     '--progress',
#     '--overwrite',
#     '--log-file',
#     'mylog.log'],
#    'start_time_utc': '2022-01-17T12:46:20.057'},
#   'input': [{'url': '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz',
#     'role': 'DL0/Event'}],
#   'output': [{'url': '/Users/jer/Desktop/curso/notebooks/events.dl1.h5',
#     'role': 'DL1/Event'}],
#   'config': {'Stage1Tool': {'config_file': None,
#     'log_config': {'version': 1,
#      'disable_existing_loggers': False,
#      'formatters': {'file': {'()': None,
#        'fmt': '%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s'},
#       'console': {'()': None,
#        'fmt': '%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s'}},
#      'handlers': {'ctapipe-console': {'class': 'logging.StreamHandler',
#        'formatter': 'console',
#        'stream': 'ext://sys.stderr',
#        'level': 30},
#       'console': {'class': 'logging.StreamHandler',
#        'formatter': 'console',
#        'stream': 'ext://sys.stderr',
#        'level': 'NOTSET'},
#       'ctapipe-file': {'class': 'logging.FileHandler',
#        'formatter': 'file',
#        'filename': '/Users/jer/Desktop/curso/notebooks/mylog.log',
#        'level': 'INFO'}},
#      'loggers': {'ctapipe': {'level': 20,
#        'handlers': ['ctapipe-console', 'ctapipe-file', 'ctapipe-file'],
#        'propagate': False}}},
#     'log_datefmt': '%Y-%m-%d %H:%M:%S',
#     'log_file': '/Users/jer/Desktop/curso/notebooks/mylog.log',
#     'log_file_level': 'INFO',
#     'log_format': '[%(name)s]%(highlevel)s %(message)s',
#     'log_level': 30,
#     'progress_bar': True,
#     'provenance_log': '/Users/jer/Desktop/curso/notebooks/ctapipe-stage1.provenance.log',
#     'quiet': False,
#     'show_config': False,
#     'show_config_json': False,
#     'SimTelEventSource': {'allowed_tels': None,
#      'back_seekable': False,
#      'focal_length_choice': 'nominal',
#      'gain_selector_type': 'ThresholdGainSelector',
#      'input_url': '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz',
#      'max_events': None,
#      'skip_calibration_events': True,
#      'ThresholdGainSelector': {'threshold': 4000.0}},
#     'CameraCalibrator': {'apply_peak_time_shift': [['type', '*', True]],
#      'apply_waveform_time_shift': [['type', '*', False]],
#      'data_volume_reducer_type': 'NullDataVolumeReducer',
#      'image_extractor_type': [['type', '*', 'NeighborPeakWindowSum']],
#      'NullDataVolumeReducer': {}},
#     'ImageProcessor': {'image_cleaner_type': 'TailcutsImageCleaner',
#      'TailcutsImageCleaner': {'boundary_threshold_pe': [['type', '*', 5.0]],
#       'keep_isolated_pixels': [['type', '*', False]],
#       'min_picture_neighbors': [['type', '*', 2]],
#       'picture_threshold_pe': [['type', '*', 10.0]]},
#      'ImageQualityQuery': {'quality_criteria': [['TOTAL', 'lambda x: True'],
#        ['size_greater_0',
#         'lambda image_selected: image_selected.sum() > 0']]}},
#     'DL1Writer': {'compression_level': 5,
#      'compression_type': 'blosc:zstd',
#      'image_dtype': 'int32',
#      'image_offset': 0,
#      'image_scale': 10.0,
#      'output_path': '/Users/jer/Desktop/curso/notebooks/events.dl1.h5',
#      'overwrite': True,
#      'peak_time_dtype': 'int16',
#      'peak_time_offset': 0,
#      'peak_time_scale': 100.0,
#      'split_datasets_by': 'tel_id',
#      'transform_image': False,
#      'transform_peak_time': False,
#      'write_images': False,
#      'write_index_tables': False,
#      'write_parameters': True,
#      'SimTelEventSource': {'allowed_tels': None,
#       'back_seekable': False,
#       'focal_length_choice': 'nominal',
#       'gain_selector_type': 'ThresholdGainSelector',
#       'input_url': '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz',
#       'max_events': None,
#       'skip_calibration_events': True,
#       'ThresholdGainSelector': {'threshold': 4000.0}},
#      'HDF5TableWriter': {}}}},
#   'status': 'completed',
#   'duration_min': 0.10381666666656741}]

# %%
type(provdata)
# Out:
# list

# %%
len(provdata)
# Out:
# 1

# %%
type(provdata[0])
# Out:
# dict

# %% [markdown]
# We can access provenance browsing the dictionary object

# %%
provdata[0]['system'].keys()
# Out:
# dict_keys(['ctapipe_version', 'ctapipe_resources_version', 'eventio_version', 'ctapipe_svc_path', 'executable', 'platform', 'python', 'environment', 'arguments', 'start_time_utc'])

# %%
provdata[0]['system']['python']['version'] # add and/or remove dict keys to browse the dict
# Out:
# ['3', '8', '12']

# %% [markdown]
# We can run again the same command and reprocess the data with eventually different parameters

# %%
# !ctapipe-stage1 --input gamma_test.simtel.gz --progress --overwrite --log-file mylog.log --log-level DEBUG
# Out:
# 2022-01-17 13:46:30,620 INFO [ctapipe.ctapipe-stage1] (tool.initialize): ctapipe version 0.11.0
# 2022-01-17 13:46:30,620 INFO [ctapipe.ctapipe-stage1] (tool.run): Starting: ctapipe-stage1
# 2022-01-17 13:46:30,643 DEBUG [ctapipe.core.provenance] (provenance.start_activity): started activity: ctapipe-stage1
# 2022-01-17 13:46:30,646 INFO [ctapipe.ctapipe-stage1.SimTelEventSource] (eventsource.__init__): INPUT PATH = /Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz
# 2022-01-17 13:46:30,646 DEBUG [ctapipe.core.provenance] (provenance.add_input_file): added input entity '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz' to activity: 'ctapipe-stage1'
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type LSTCam
#   warnings.warn(
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type NectarCam
#   warnings.warn(
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type CHEC
#   warnings.warn(
# /opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages/ctapipe/io/simteleventsource.py:70: UnknownPixelShapeWarning: Unkown pixel_shape -1.0 for camera_type SCTCam
#   warnings.warn(
# 2022-01-17 13:46:31,444 DEBUG [ctapipe.ctapipe-stage1.SimTelEventSource] (simteleventsource.__init__): Using gain selector <ctapipe.calib.camera.gainselection.ThresholdGainSelector object at 0x7fa72c8b15e0>
# 2022-01-17 13:46:31,507 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,564 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,631 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,685 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,742 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,797 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,852 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,905 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:31,959 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:32,011 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:32,055 DEBUG [ctapipe.core.traits] (traits.attach_subarray): argument '*' matched: ['SST_ASTRI_CHEC', 'MST_SCT_SCTCam', 'MST_MST_NectarCam', 'LST_LST_LSTCam']
# 2022-01-17 13:46:32,058 WARNING [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_output_path): Overwriting /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# 2022-01-17 13:46:32,058 DEBUG [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_output_path): output path: /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# 2022-01-17 13:46:32,058 DEBUG [ctapipe.core.provenance] (provenance.add_output_file): added output entity '/Users/jer/Desktop/curso/notebooks/events.dl1.h5' to activity: 'ctapipe-stage1'
# 2022-01-17 13:46:32,299 DEBUG [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_compression): compression filters: Filters(complevel=5, complib='blosc:zstd', shuffle=True, bitshuffle=False, fletcher32=True, least_significant_digit=None)
# 2022-01-17 13:46:32,299 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio.open): kwargs for tables.open_file: {'mode': 'a', 'root_uep': '/', 'filters': Filters(complevel=5, complib='blosc:zstd', shuffle=True, bitshuffle=False, fletcher32=True, least_significant_digit=None)}
# 2022-01-17 13:46:32,300 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio.__init__): h5file: /Users/jer/Desktop/curso/notebooks/events.dl1.h5 (File) ''
# Last modif.: 'Mon Jan 17 13:46:32 2022'
# Object Tree:
# / (RootGroup) ''
# /configuration (Group) ''
# /configuration/instrument (Group) ''
# /configuration/instrument/subarray (Group) ''
# /configuration/instrument/subarray/layout (Table(126,)) ''
# /configuration/instrument/subarray/layout.__table_column_meta__ (Array(16,)) ''
# /configuration/instrument/telescope (Group) ''
# /configuration/instrument/telescope/optics (Table(4,)) ''
# /configuration/instrument/telescope/optics.__table_column_meta__ (Array(14,)) ''
# /configuration/instrument/telescope/camera (Group) ''
# /configuration/instrument/telescope/camera/geometry_CHEC (Table(2048,)) ''
# /configuration/instrument/telescope/camera/geometry_CHEC.__table_column_meta__ (Array(6,)) ''
# /configuration/instrument/telescope/camera/geometry_LSTCam (Table(1855,)) ''
# /configuration/instrument/telescope/camera/geometry_LSTCam.__table_column_meta__ (Array(6,)) ''
# /configuration/instrument/telescope/camera/geometry_NectarCam (Table(1855,)) ''
# /configuration/instrument/telescope/camera/geometry_NectarCam.__table_column_meta__ (Array(7,)) ''
# /configuration/instrument/telescope/camera/geometry_SCTCam (Table(11328,)) ''
# /configuration/instrument/telescope/camera/geometry_SCTCam.__table_column_meta__ (Array(6,)) ''
# /configuration/instrument/telescope/camera/readout_CHEC (Table(80,)) ''
# /configuration/instrument/telescope/camera/readout_CHEC.__table_column_meta__ (Array(5,)) ''
# /configuration/instrument/telescope/camera/readout_LSTCam (Table(240,)) ''
# /configuration/instrument/telescope/camera/readout_LSTCam.__table_column_meta__ (Array(4,)) ''
# /configuration/instrument/telescope/camera/readout_NectarCam (Table(210,)) ''
# /configuration/instrument/telescope/camera/readout_NectarCam.__table_column_meta__ (Array(4,)) ''
# /configuration/instrument/telescope/camera/readout_SCTCam (Table(200,)) ''
# /configuration/instrument/telescope/camera/readout_SCTCam.__table_column_meta__ (Array(4,)) ''
#
# 2022-01-17 13:46:32,316 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/subarray/trigger/tels_with_trigger -> <bound method SubarrayDescription.tel_ids_to_mask of SubarrayDescription(name='MonteCarloArray', num_tels=126)>
# 2022-01-17 13:46:32,368 DEBUG [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_writer): Writer initialized: <ctapipe.io.hdf5tableio.HDF5TableWriter object at 0x7fa72c8cfe80>
# 2022-01-17 13:46:32,369 DEBUG [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._write_simulation_configuration): Writing simulation configuration
# 2022-01-17 13:46:32,369 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'configuration/simulation/run' in group '/'
# 2022-01-17 13:46:32,369 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: obs_id type: int32 shape: 1 with transform: None
# 2022-01-17 13:46:32,370 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_version type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,370 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: simtel_version type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,370 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/energy_range_min -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72716b970>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: energy_range_min type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72716b970>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/energy_range_max -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72716b9a0>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: energy_range_max type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72716b9a0>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/prod_site_B_total -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa726f32430>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: prod_site_B_total type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa726f32430>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/prod_site_B_declination -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa726f32d60>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: prod_site_B_declination type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa726f32d60>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/prod_site_B_inclination -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f610>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: prod_site_B_inclination type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f610>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/prod_site_alt -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735fd30>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: prod_site_alt type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735fd30>
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: spectral_index type: float shape: 1 with transform: None
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: shower_prog_start type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: shower_prog_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,375 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: detector_prog_start type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: detector_prog_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: num_showers type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: shower_reuse type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/max_alt -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f0a0>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: max_alt type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f0a0>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/min_alt -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f160>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: min_alt type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f160>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/max_az -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f190>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: max_az type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f190>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/min_az -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f2e0>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: min_az type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f2e0>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: diffuse type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/max_viewcone_radius -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f460>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: max_viewcone_radius type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f460>
# 2022-01-17 13:46:32,376 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/min_viewcone_radius -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f520>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: min_viewcone_radius type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735f520>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/max_scatter_range -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735ff10>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: max_scatter_range type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa72735ff10>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/min_scatter_range -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371ee0>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: min_scatter_range type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371ee0>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: core_pos_mode type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/injection_height -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371580>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: injection_height type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371580>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: atmosphere type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_iact_options type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_low_E_model type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_high_E_model type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_bunchsize type: float shape: 1 with transform: None
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/corsika_wlen_min -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371fa0>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_wlen_min type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371fa0>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: configuration/simulation/run/corsika_wlen_max -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371280>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_wlen_max type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727371280>
# 2022-01-17 13:46:32,377 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_low_E_detail type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,378 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table configuration/simulation/run: added col: corsika_high_E_detail type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,387 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): CREATED TABLE: /configuration/simulation/run (Table(0,), fletcher32, shuffle, blosc:zstd(5)) 'Storage of ExtraSimInfo,SimulationConfigContainer'
# 2022-01-17 13:46:32,401 DEBUG [ctapipe.ctapipe-stage1] (tool.run): CONFIG: {'Stage1Tool': {'config_file': None, 'log_config': {'version': 1, 'disable_existing_loggers': False, 'formatters': {'file': {'()': <class 'ctapipe.core.logging.PlainFormatter'>, 'fmt': '%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s'}, 'console': {'()': <class 'ctapipe.core.logging.ColoredFormatter'>, 'fmt': '%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s'}}, 'handlers': {'ctapipe-console': {'class': 'logging.StreamHandler', 'formatter': 'console', 'stream': 'ext://sys.stderr', 'level': 10}, 'console': {'class': 'logging.StreamHandler', 'formatter': 'console', 'stream': 'ext://sys.stderr', 'level': 'NOTSET'}, 'ctapipe-file': {'class': 'logging.FileHandler', 'formatter': 'file', 'filename': PosixPath('/Users/jer/Desktop/curso/notebooks/mylog.log'), 'level': 'INFO'}}, 'loggers': {'ctapipe': {'level': 10, 'handlers': ['ctapipe-console', 'ctapipe-file', 'ctapipe-file'], 'propagate': False}}}, 'log_datefmt': '%Y-%m-%d %H:%M:%S', 'log_file': PosixPath('/Users/jer/Desktop/curso/notebooks/mylog.log'), 'log_file_level': 'INFO', 'log_format': '[%(name)s]%(highlevel)s %(message)s', 'log_level': 10, 'progress_bar': True, 'provenance_log': PosixPath('/Users/jer/Desktop/curso/notebooks/ctapipe-stage1.provenance.log'), 'quiet': False, 'show_config': False, 'show_config_json': False, 'SimTelEventSource': {'allowed_tels': None, 'back_seekable': False, 'focal_length_choice': 'nominal', 'gain_selector_type': 'ThresholdGainSelector', 'input_url': PosixPath('/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz'), 'max_events': None, 'skip_calibration_events': True, 'ThresholdGainSelector': {'threshold': 4000.0}}, 'CameraCalibrator': {'apply_peak_time_shift': [('type', '*', True)], 'apply_waveform_time_shift': [('type', '*', False)], 'data_volume_reducer_type': 'NullDataVolumeReducer', 'image_extractor_type': [('type', '*', 'NeighborPeakWindowSum')], 'NullDataVolumeReducer': {}}, 'ImageProcessor': {'image_cleaner_type': 'TailcutsImageCleaner', 'TailcutsImageCleaner': {'boundary_threshold_pe': [('type', '*', 5.0)], 'keep_isolated_pixels': [('type', '*', False)], 'min_picture_neighbors': [('type', '*', 2)], 'picture_threshold_pe': [('type', '*', 10.0)]}, 'ImageQualityQuery': {'quality_criteria': [('TOTAL', 'lambda x: True'), ('size_greater_0', 'lambda image_selected: image_selected.sum() > 0')]}}, 'DL1Writer': {'compression_level': 5, 'compression_type': 'blosc:zstd', 'image_dtype': 'int32', 'image_offset': 0, 'image_scale': 10.0, 'output_path': PosixPath('/Users/jer/Desktop/curso/notebooks/events.dl1.h5'), 'overwrite': True, 'peak_time_dtype': 'int16', 'peak_time_offset': 0, 'peak_time_scale': 100.0, 'split_datasets_by': 'tel_id', 'transform_image': False, 'transform_peak_time': False, 'write_images': False, 'write_index_tables': False, 'write_parameters': True, 'SimTelEventSource': {'allowed_tels': None, 'back_seekable': False, 'focal_length_choice': 'nominal', 'gain_selector_type': 'ThresholdGainSelector', 'input_url': PosixPath('/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz'), 'max_events': None, 'skip_calibration_events': True, 'ThresholdGainSelector': {'threshold': 4000.0}}, 'HDF5TableWriter': {}}}}
# 2022-01-17 13:46:32,402 INFO [ctapipe.ctapipe-stage1] (subarray.info): Subarray : MonteCarloArray
# 2022-01-17 13:46:32,402 INFO [ctapipe.ctapipe-stage1] (subarray.info): Num Tels : 126
# 2022-01-17 13:46:32,403 INFO [ctapipe.ctapipe-stage1] (subarray.info): Footprint: 7.32 km2
# 2022-01-17 13:46:32,403 INFO [ctapipe.ctapipe-stage1] (subarray.info):
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):        Type       Count Tel IDs
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info): ----------------- ----- -------
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):    SST_ASTRI_CHEC    72 29-100
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):    MST_SCT_SCTCam    26 101-126
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info): MST_MST_NectarCam    24 5-28
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):    LST_LST_LSTCam     4 1-4
# SimTelEventSource: 0ev [00:00, ?ev/s]OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 2022-01-17 13:46:32,742 DEBUG [ctapipe.ctapipe-stage1.ImageProcessor] (image_processor._parameterize_image): image_criteria: [('size_greater_0', False)]
# 2022-01-17 13:46:32,742 DEBUG [ctapipe.ctapipe-stage1.ImageProcessor] (image_processor._process_telescope_event): params: {'hillas': {'intensity': nan, 'x': <Quantity nan m>, 'y': <Quantity nan m>, 'r': <Quantity nan m>, 'phi': <Quantity nan deg>, 'length': <Quantity nan m>, 'length_uncertainty': <Quantity nan m>, 'width': <Quantity nan m>, 'width_uncertainty': <Quantity nan m>, 'psi': <Quantity nan deg>, 'skewness': nan, 'kurtosis': nan}, 'timing': {'slope': <Quantity nan 1 / m>, 'intercept': nan, 'deviation': nan}, 'leakage': {'pixels_width_1': nan, 'pixels_width_2': nan, 'intensity_width_1': nan, 'intensity_width_2': nan}, 'concentration': {'cog': nan, 'core': nan, 'pixel': nan}, 'morphology': {'num_pixels': -1, 'num_islands': -1, 'num_small_islands': -1, 'num_medium_islands': -1, 'num_large_islands': -1}, 'intensity_statistics': {'max': nan, 'min': nan, 'mean': nan, 'std': nan, 'skewness': nan, 'kurtosis': nan}, 'peak_time_statistics': {'max': nan, 'min': nan, 'mean': nan, 'std': nan, 'skewness': nan, 'kurtosis': nan}}
# 2022-01-17 13:46:32,743 DEBUG [ctapipe.ctapipe-stage1.ImageProcessor] (image_processor._parameterize_image): image_criteria: [('size_greater_0', False)]
# 2022-01-17 13:46:32,743 DEBUG [ctapipe.ctapipe-stage1.ImageProcessor] (image_processor._process_telescope_event): params: {'hillas': {'intensity': nan, 'x': <Quantity nan m>, 'y': <Quantity nan m>, 'r': <Quantity nan m>, 'phi': <Quantity nan deg>, 'length': <Quantity nan m>, 'length_uncertainty': <Quantity nan m>, 'width': <Quantity nan m>, 'width_uncertainty': <Quantity nan m>, 'psi': <Quantity nan deg>, 'skewness': nan, 'kurtosis': nan}, 'timing': {'slope': <Quantity nan 1 / m>, 'intercept': nan, 'deviation': nan}, 'leakage': {'pixels_width_1': nan, 'pixels_width_2': nan, 'intensity_width_1': nan, 'intensity_width_2': nan}, 'concentration': {'cog': nan, 'core': nan, 'pixel': nan}, 'morphology': {'num_pixels': -1, 'num_islands': -1, 'num_small_islands': -1, 'num_medium_islands': -1, 'num_large_islands': -1}, 'intensity_statistics': {'max': nan, 'min': nan, 'mean': nan, 'std': nan, 'skewness': nan, 'kurtosis': nan}, 'peak_time_statistics': {'max': nan, 'min': nan, 'mean': nan, 'std': nan, 'skewness': nan, 'kurtosis': nan}}
# 2022-01-17 13:46:32,744 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'dl1/monitoring/subarray/pointing' in group '/'
# 2022-01-17 13:46:32,745 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/subarray/pointing/time -> <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa7273d72e0>
# 2022-01-17 13:46:32,745 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/subarray/pointing: added col: time type:  shape: 1 with transform: <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa7273d72e0>
# 2022-01-17 13:46:32,745 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/monitoring/subarray/pointing/tels_with_trigger
# 2022-01-17 13:46:32,745 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/monitoring/subarray/pointing/event_type
# 2022-01-17 13:46:32,745 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/monitoring/subarray/pointing/tel
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/monitoring/subarray/pointing/tel
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/subarray/pointing/array_azimuth -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7273d73a0>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/subarray/pointing: added col: array_azimuth type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7273d73a0>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/subarray/pointing/array_altitude -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727458880>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/subarray/pointing: added col: array_altitude type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727458880>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/subarray/pointing/array_ra -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727458460>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/subarray/pointing: added col: array_ra type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727458460>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/subarray/pointing/array_dec -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7274584f0>
# 2022-01-17 13:46:32,746 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/subarray/pointing: added col: array_dec type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7274584f0>
# 2022-01-17 13:46:32,750 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): CREATED TABLE: /dl1/monitoring/subarray/pointing (Table(0,), fletcher32, shuffle, blosc:zstd(5)) 'Storage of TriggerContainer,PointingContainer'
# 2022-01-17 13:46:32,760 DEBUG [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer.__call__): WRITING EVENT {'event_id': 408, 'obs_id': 31964}
# 2022-01-17 13:46:32,761 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'dl1/event/subarray/trigger' in group '/'
# 2022-01-17 13:46:32,761 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/subarray/trigger: added col: obs_id type: int32 shape: 1 with transform: None
# 2022-01-17 13:46:32,761 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/subarray/trigger: added col: event_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,761 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/subarray/trigger/time -> <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa727289fa0>
# 2022-01-17 13:46:32,761 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/subarray/trigger: added col: time type:  shape: 1 with transform: <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa727289fa0>
# 2022-01-17 13:46:32,762 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/subarray/trigger: added col: tels_with_trigger type: bool shape: (126,) with transform: <bound method SubarrayDescription.tel_ids_to_mask of SubarrayDescription(name='MonteCarloArray', num_tels=126)>
# 2022-01-17 13:46:32,762 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/subarray/trigger/event_type -> <ctapipe.io.tableio.EnumColumnTransform object at 0x7fa727289be0>
# 2022-01-17 13:46:32,762 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/subarray/trigger: added col: event_type type: int shape: 1 with transform: <ctapipe.io.tableio.EnumColumnTransform object at 0x7fa727289be0>
# 2022-01-17 13:46:32,762 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/event/subarray/trigger/tel
# 2022-01-17 13:46:32,765 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): CREATED TABLE: /dl1/event/subarray/trigger (Table(0,), fletcher32, shuffle, blosc:zstd(5)) 'Storage of EventIndexContainer,TriggerContainer'
# 2022-01-17 13:46:32,766 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'simulation/event/subarray/shower' in group '/'
# 2022-01-17 13:46:32,766 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: obs_id type: int32 shape: 1 with transform: None
# 2022-01-17 13:46:32,766 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: event_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_energy -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232a90>
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_energy type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232a90>
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_alt -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272324c0>
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_alt type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272324c0>
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_az -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272325e0>
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_az type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272325e0>
# 2022-01-17 13:46:32,767 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_core_x -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232220>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_core_x type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232220>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_core_y -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272328e0>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_core_y type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272328e0>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_h_first_int -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232370>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_h_first_int type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232370>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: simulation/event/subarray/shower/true_x_max -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232f10>
# 2022-01-17 13:46:32,768 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_x_max type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727232f10>
# 2022-01-17 13:46:32,769 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table simulation/event/subarray/shower: added col: true_shower_primary_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,774 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): CREATED TABLE: /simulation/event/subarray/shower (Table(0,), fletcher32, shuffle, blosc:zstd(5)) 'Storage of EventIndexContainer,SimulatedShowerContainer'
# 2022-01-17 13:46:32,776 DEBUG [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._write_telescope_events): WRITING TELESCOPE 38: SST_ASTRI_CHEC
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'dl1/monitoring/telescope/pointing/tel_038' in group '/'
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/telescope/pointing/tel_038/time -> <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa727224070>
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/telescope/pointing/tel_038: added col: time type:  shape: 1 with transform: <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa727224070>
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/monitoring/telescope/pointing/tel_038/n_trigger_pixels
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/monitoring/telescope/pointing/tel_038/trigger_pixels
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/telescope/pointing/tel_038/azimuth -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727224460>
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/telescope/pointing/tel_038: added col: azimuth type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727224460>
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/monitoring/telescope/pointing/tel_038/altitude -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727224100>
# 2022-01-17 13:46:32,777 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/monitoring/telescope/pointing/tel_038: added col: altitude type: float32 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727224100>
# 2022-01-17 13:46:32,780 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): CREATED TABLE: /dl1/monitoring/telescope/pointing/tel_038 (Table(0,), fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelescopeTriggerContainer,TelescopePointingContainer'
# 2022-01-17 13:46:32,781 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'dl1/event/telescope/trigger' in group '/'
# 2022-01-17 13:46:32,781 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/trigger: added col: obs_id type: int32 shape: 1 with transform: None
# 2022-01-17 13:46:32,782 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/trigger: added col: event_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,782 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/trigger: added col: tel_id type: int16 shape: 1 with transform: None
# 2022-01-17 13:46:32,782 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/telescope/trigger/time -> <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa72722f7c0>
# 2022-01-17 13:46:32,782 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/trigger: added col: time type:  shape: 1 with transform: <ctapipe.io.tableio.TimeColumnTransform object at 0x7fa72722f7c0>
# 2022-01-17 13:46:32,782 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/trigger: added col: n_trigger_pixels type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,782 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): excluded column: dl1/event/telescope/trigger/trigger_pixels
# 2022-01-17 13:46:32,784 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): CREATED TABLE: /dl1/event/telescope/trigger (Table(0,), fletcher32, shuffle, blosc:zstd(5)) 'Storage of TelEventIndexContainer,TelescopeTriggerContainer'
# 2022-01-17 13:46:32,786 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._setup_new_table): Initializing table 'dl1/event/telescope/parameters/tel_038' in group '/'
# 2022-01-17 13:46:32,786 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: obs_id type: int32 shape: 1 with transform: None
# 2022-01-17 13:46:32,786 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: event_id type: int shape: 1 with transform: None
# 2022-01-17 13:46:32,786 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: tel_id type: int16 shape: 1 with transform: None
# 2022-01-17 13:46:32,786 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: hillas_intensity type: float shape: 1 with transform: None
# 2022-01-17 13:46:32,786 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/telescope/parameters/tel_038/hillas_x -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727253430>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: hillas_x type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727253430>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/telescope/parameters/tel_038/hillas_y -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272532e0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: hillas_y type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa7272532e0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/telescope/parameters/tel_038/hillas_r -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727253be0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: hillas_r type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727253be0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/telescope/parameters/tel_038/hillas_phi -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727355cd0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: hillas_phi type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727355cd0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (tableio.add_column_transform): Added transform: dl1/event/telescope/parameters/tel_038/hillas_length -> <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727355dc0>
# 2022-01-17 13:46:32,787 DEBUG [ctapipe.ctapipe-stage1.DL1Writer.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Table dl1/event/telescope/parameters/tel_038: added col: hillas_length type: float64 shape: 1 with transform: <ctapipe.io.tableio.QuantityColumnTransform object at 0x7fa727355dc0>
# ...
#                },
#                {
#                   "name": "scikit-learn",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "scipy",
#                   "version": "1.7.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "seaborn",
#                   "version": "0.11.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "setuptools",
#                   "version": "59.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "setuptools-scm",
#                   "version": "6.3.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "six",
#                   "version": "1.16.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sniffio",
#                   "version": "1.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "snowballstemmer",
#                   "version": "2.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sortedcontainers",
#                   "version": "2.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-argparse",
#                   "version": "0.3.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-automodapi",
#                   "version": "0.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-rtd-theme",
#                   "version": "1.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-applehelp",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-devhelp",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-htmlhelp",
#                   "version": "2.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-jsmath",
#                   "version": "1.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-qthelp",
#                   "version": "1.0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-serializinghtml",
#                   "version": "1.1.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "stack-data",
#                   "version": "0.1.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "statsmodels",
#                   "version": "0.13.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tables",
#                   "version": "3.6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "terminado",
#                   "version": "0.12.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "testpath",
#                   "version": "0.5.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "threadpoolctl",
#                   "version": "3.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "toml",
#                   "version": "0.10.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tomli",
#                   "version": "1.2.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tornado",
#                   "version": "6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tqdm",
#                   "version": "4.62.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "traitlets",
#                   "version": "5.0.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "typed-ast",
#                   "version": "1.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "typing-extensions",
#                   "version": "4.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "urllib3",
#                   "version": "1.26.8",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "wcwidth",
#                   "version": "0.2.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "webencodings",
#                   "version": "0.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "wheel",
#                   "version": "0.37.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "widgetsnbextension",
#                   "version": "3.5.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "zipp",
#                   "version": "3.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "zstandard",
#                   "version": "0.16.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                }
#             ]
#          },
#          "environment": {
#             "CONDA_DEFAULT_ENV": "lst-school-2022-01",
#             "CONDA_PREFIX": "/opt/miniconda3/envs/lst-school-2022-01",
#             "CONDA_PYTHON_EXE": "/opt/miniconda3/bin/python",
#             "CONDA_EXE": "/opt/miniconda3/bin/conda",
#             "CONDA_PROMPT_MODIFIER": "(lst-school-2022-01) ",
#             "CONDA_SHLVL": "2",
#             "PATH": "/Users/jer/.rbenv/shims:/opt/miniconda3/envs/lst-school-2022-01/bin:/opt/miniconda3/condabin:/Users/jer/root/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin:/Library/TeX/texbin:/opt/X11/bin",
#             "LD_LIBRARY_PATH": "/Users/jer/root/lib",
#             "DYLD_LIBRARY_PATH": null,
#             "USER": "jer",
#             "HOME": "/Users/jer",
#             "SHELL": "/bin/zsh"
#          },
#          "arguments": [
#             "/opt/miniconda3/envs/lst-school-2022-01/bin/ctapipe-stage1",
#             "--input",
#             "gamma_test.simtel.gz",
#             "--progress",
#             "--overwrite",
#             "--log-file",
#             "mylog.log",
#             "--log-level",
#             "DEBUG"
#          ],
#          "start_time_utc": "2022-01-17T12:46:30.644"
#       },
#       "input": [
#          {
#             "url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#             "role": "DL0/Event"
#          }
#       ],
#       "output": [
#          {
#             "url": "/Users/jer/Desktop/curso/notebooks/events.dl1.h5",
#             "role": "DL1/Event"
#          }
#       ],
#       "config": {
#          "Stage1Tool": {
#             "config_file": null,
#             "log_config": {
#                "version": 1,
#                "disable_existing_loggers": false,
#                "formatters": {
#                   "file": {
#                      "()": null,
#                      "fmt": "%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s"
#                   },
#                   "console": {
#                      "()": null,
#                      "fmt": "%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s"
#                   }
#                },
#                "handlers": {
#                   "ctapipe-console": {
#                      "class": "logging.StreamHandler",
#                      "formatter": "console",
#                      "stream": "ext://sys.stderr",
#                      "level": 10
#                   },
#                   "console": {
#                      "class": "logging.StreamHandler",
#                      "formatter": "console",
#                      "stream": "ext://sys.stderr",
#                      "level": "NOTSET"
#                   },
#                   "ctapipe-file": {
#                      "class": "logging.FileHandler",
#                      "formatter": "file",
#                      "filename": "/Users/jer/Desktop/curso/notebooks/mylog.log",
#                      "level": "INFO"
#                   }
#                },
#                "loggers": {
#                   "ctapipe": {
#                      "level": 10,
#                      "handlers": [
#                         "ctapipe-console",
#                         "ctapipe-file",
#                         "ctapipe-file"
#                      ],
#                      "propagate": false
#                   }
#                }
#             },
#             "log_datefmt": "%Y-%m-%d %H:%M:%S",
#             "log_file": "/Users/jer/Desktop/curso/notebooks/mylog.log",
#             "log_file_level": "INFO",
#             "log_format": "[%(name)s]%(highlevel)s %(message)s",
#             "log_level": 10,
#             "progress_bar": true,
#             "provenance_log": "/Users/jer/Desktop/curso/notebooks/ctapipe-stage1.provenance.log",
#             "quiet": false,
#             "show_config": false,
#             "show_config_json": false,
#             "SimTelEventSource": {
#                "allowed_tels": null,
#                "back_seekable": false,
#                "focal_length_choice": "nominal",
#                "gain_selector_type": "ThresholdGainSelector",
#                "input_url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#                "max_events": null,
#                "skip_calibration_events": true,
#                "ThresholdGainSelector": {
#                   "threshold": 4000.0
#                }
#             },
#             "CameraCalibrator": {
#                "apply_peak_time_shift": [
#                   [
#                      "type",
#                      "*",
#                      true
#                   ]
#                ],
#                "apply_waveform_time_shift": [
#                   [
#                      "type",
#                      "*",
#                      false
#                   ]
#                ],
#                "data_volume_reducer_type": "NullDataVolumeReducer",
#                "image_extractor_type": [
#                   [
#                      "type",
#                      "*",
#                      "NeighborPeakWindowSum"
#                   ]
#                ],
#                "NullDataVolumeReducer": {}
#             },
#             "ImageProcessor": {
#                "image_cleaner_type": "TailcutsImageCleaner",
#                "TailcutsImageCleaner": {
#                   "boundary_threshold_pe": [
#                      [
#                         "type",
#                         "*",
#                         5.0
#                      ]
#                   ],
#                   "keep_isolated_pixels": [
#                      [
#                         "type",
#                         "*",
#                         false
#                      ]
#                   ],
#                   "min_picture_neighbors": [
#                      [
#                         "type",
#                         "*",
#                         2
#                      ]
#                   ],
#                   "picture_threshold_pe": [
#                      [
#                         "type",
#                         "*",
#                         10.0
#                      ]
#                   ]
#                },
#                "ImageQualityQuery": {
#                   "quality_criteria": [
#                      [
#                         "TOTAL",
#                         "lambda x: True"
#                      ],
#                      [
#                         "size_greater_0",
#                         "lambda image_selected: image_selected.sum() > 0"
#                      ]
#                   ]
#                }
#             },
#             "DL1Writer": {
#                "compression_level": 5,
#                "compression_type": "blosc:zstd",
#                "image_dtype": "int32",
#                "image_offset": 0,
#                "image_scale": 10.0,
#                "output_path": "/Users/jer/Desktop/curso/notebooks/events.dl1.h5",
#                "overwrite": true,
#                "peak_time_dtype": "int16",
#                "peak_time_offset": 0,
#                "peak_time_scale": 100.0,
#                "split_datasets_by": "tel_id",
#                "transform_image": false,
#                "transform_peak_time": false,
#                "write_images": false,
#                "write_index_tables": false,
#                "write_parameters": true,
#                "SimTelEventSource": {
#                   "allowed_tels": null,
#                   "back_seekable": false,
#                   "focal_length_choice": "nominal",
#                   "gain_selector_type": "ThresholdGainSelector",
#                   "input_url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#                   "max_events": null,
#                   "skip_calibration_events": true,
#                   "ThresholdGainSelector": {
#                      "threshold": 4000.0
#                   }
#                },
#                "HDF5TableWriter": {}
#             }
#          }
#       },
#       "status": "completed",
#       "duration_min": 0.11183333333322665
#    }
# ]'
# 2022-01-17 13:46:37,341 DEBUG [ctapipe.ctapipe-stage1] (application.exit): Exiting application: ctapipe-stage1

# %% [markdown]
# We still have the same log files

# %%
# !ls *.log
# Out:
# ctapipe-stage1.provenance.log mylog.log

# %% [markdown]
# The log content produced in this second execution has been **appended** both log files

# %%
# !cat mylog.log
# Out:
# 2022-01-17 13:46:20,035 INFO [ctapipe.ctapipe-stage1] (tool.initialize): ctapipe version 0.11.0
# 2022-01-17 13:46:20,035 INFO [ctapipe.ctapipe-stage1] (tool.run): Starting: ctapipe-stage1
# 2022-01-17 13:46:20,060 INFO [ctapipe.ctapipe-stage1.SimTelEventSource] (eventsource.__init__): INPUT PATH = /Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz
# 2022-01-17 13:46:21,296 WARNING [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_output_path): Overwriting /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# 2022-01-17 13:46:21,562 INFO [ctapipe.ctapipe-stage1] (subarray.info): Subarray : MonteCarloArray
# 2022-01-17 13:46:21,562 INFO [ctapipe.ctapipe-stage1] (subarray.info): Num Tels : 126
# 2022-01-17 13:46:21,563 INFO [ctapipe.ctapipe-stage1] (subarray.info): Footprint: 7.32 km2
# 2022-01-17 13:46:21,563 INFO [ctapipe.ctapipe-stage1] (subarray.info):
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):        Type       Count Tel IDs
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info): ----------------- ----- -------
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):    SST_ASTRI_CHEC    72 29-100
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):    MST_SCT_SCTCam    26 101-126
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info): MST_MST_NectarCam    24 5-28
# 2022-01-17 13:46:21,600 INFO [ctapipe.ctapipe-stage1] (subarray.info):    LST_LST_LSTCam     4 1-4
# 2022-01-17 13:46:26,178 WARNING [ctapipe.ctapipe-stage1.SimTelEventSource] (simteleventsource._generator): EOFError reading from "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz". Might be truncated
# 2022-01-17 13:46:26,181 INFO [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer.finish): Finishing DL1 output
# 2022-01-17 13:46:26,264 INFO [ctapipe.ctapipe-stage1] (tool.run): Finished: ctapipe-stage1
# 2022-01-17 13:46:26,265 INFO [ctapipe.ctapipe-stage1] (tool.write_provenance): Output: /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# 2022-01-17 13:46:30,620 INFO [ctapipe.ctapipe-stage1] (tool.initialize): ctapipe version 0.11.0
# 2022-01-17 13:46:30,620 INFO [ctapipe.ctapipe-stage1] (tool.run): Starting: ctapipe-stage1
# 2022-01-17 13:46:30,646 INFO [ctapipe.ctapipe-stage1.SimTelEventSource] (eventsource.__init__): INPUT PATH = /Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz
# 2022-01-17 13:46:32,058 WARNING [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer._setup_output_path): Overwriting /Users/jer/Desktop/curso/notebooks/events.dl1.h5
# 2022-01-17 13:46:32,402 INFO [ctapipe.ctapipe-stage1] (subarray.info): Subarray : MonteCarloArray
# 2022-01-17 13:46:32,402 INFO [ctapipe.ctapipe-stage1] (subarray.info): Num Tels : 126
# 2022-01-17 13:46:32,403 INFO [ctapipe.ctapipe-stage1] (subarray.info): Footprint: 7.32 km2
# 2022-01-17 13:46:32,403 INFO [ctapipe.ctapipe-stage1] (subarray.info):
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):        Type       Count Tel IDs
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info): ----------------- ----- -------
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):    SST_ASTRI_CHEC    72 29-100
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):    MST_SCT_SCTCam    26 101-126
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info): MST_MST_NectarCam    24 5-28
# 2022-01-17 13:46:32,448 INFO [ctapipe.ctapipe-stage1] (subarray.info):    LST_LST_LSTCam     4 1-4
# 2022-01-17 13:46:37,249 WARNING [ctapipe.ctapipe-stage1.SimTelEventSource] (simteleventsource._generator): EOFError reading from "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz". Might be truncated
# 2022-01-17 13:46:37,251 INFO [ctapipe.ctapipe-stage1.DL1Writer] (dl1writer.finish): Finishing DL1 output
# 2022-01-17 13:46:37,330 INFO [ctapipe.ctapipe-stage1] (tool.run): Finished: ctapipe-stage1
# 2022-01-17 13:46:37,332 INFO [ctapipe.ctapipe-stage1] (tool.write_provenance): Output: /Users/jer/Desktop/curso/notebooks/events.dl1.h5

# %% [markdown]
# While classic timestamped log file `mylog.log` is still easy readable, the content of `ctapipe-stage1.provenance.log` is the concatenation of two JSON objects issued from the two executions of the `ctapipe-stage1` tool.

# %%
# !cat ctapipe-stage1.provenance.log
# Out:
# [
#    {
#       "activity_name": "ctapipe-stage1",
#       "activity_uuid": "491e433c-06d1-4199-b714-f81b93846076",
#       "start": {
#          "time_utc": "2022-01-17T12:46:20.036"
#       },
#       "stop": {
#          "time_utc": "2022-01-17T12:46:26.265"
#       },
#       "system": {
#          "ctapipe_version": "0.11.0",
#          "ctapipe_resources_version": "not installed",
#          "eventio_version": "1.5.1.post1",
#          "ctapipe_svc_path": "/Users/jer/git/cta-observatory/ctapipe-extra/ctapipe_resources",
#          "executable": "/opt/miniconda3/envs/lst-school-2022-01/bin/python",
#          "platform": {
#             "architecture_bits": "64bit",
#             "architecture_linkage": "",
#             "machine": "x86_64",
#             "processor": "i386",
#             "node": "Joses-MacBook-Pro.local",
#             "version": "Darwin Kernel Version 21.2.0: Sun Nov 28 20:28:54 PST 2021; root:xnu-8019.61.5~1/RELEASE_X86_64",
#             "system": "Darwin",
#             "release": "21.2.0",
#             "libcver": [
#                "",
#                ""
#             ],
#             "num_cpus": 8,
#             "boot_time": "2021-12-14T21:43:28.000"
#          },
#          "python": {
#             "version_string": "3.8.12 | packaged by conda-forge | (default, Oct 12 2021, 21:50:56) \n[Clang 11.1.0 ]",
#             "version": [
#                "3",
#                "8",
#                "12"
#             ],
#             "compiler": "Clang 11.1.0 ",
#             "implementation": "CPython",
#             "packages": [
#                {
#                   "name": "Babel",
#                   "version": "2.9.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "Jinja2",
#                   "version": "3.0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "MarkupSafe",
#                   "version": "2.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "Pillow",
#                   "version": "8.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "PyQt5",
#                   "version": "5.12.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "PyQt5-sip",
#                   "version": "4.19.18",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "PyQtChart",
#                   "version": "5.12",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "PyQtWebEngine",
#                   "version": "5.12.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "PySocks",
#                   "version": "1.7.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "PyYAML",
#                   "version": "6.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "Pygments",
#                   "version": "2.11.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "QtPy",
#                   "version": "2.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "Send2Trash",
#                   "version": "1.8.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "Sphinx",
#                   "version": "4.3.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ViTables",
#                   "version": "3.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "alabaster",
#                   "version": "0.7.12",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "anyio",
#                   "version": "2.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "appnope",
#                   "version": "0.1.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "argon2-cffi",
#                   "version": "21.3.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "argon2-cffi-bindings",
#                   "version": "21.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "astropy",
#                   "version": "4.3.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "asttokens",
#                   "version": "2.0.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "attrs",
#                   "version": "21.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "backcall",
#                   "version": "0.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "backports.functools-lru-cache",
#                   "version": "1.6.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "black",
#                   "version": "21.12b0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "bleach",
#                   "version": "4.1.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "bokeh",
#                   "version": "1.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "brotlipy",
#                   "version": "0.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "cached-property",
#                   "version": "1.5.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "certifi",
#                   "version": "2021.10.8",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "cffi",
#                   "version": "1.15.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "charset-normalizer",
#                   "version": "2.0.10",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "click",
#                   "version": "8.0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "colorama",
#                   "version": "0.4.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "commonmark",
#                   "version": "0.9.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "corsikaio",
#                   "version": "0.2.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "coverage",
#                   "version": "6.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "cryptography",
#                   "version": "36.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ctapipe",
#                   "version": "0.11.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ctapipe-io-lst",
#                   "version": "0.13.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ctaplot",
#                   "version": "0.5.6",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "cycler",
#                   "version": "0.11.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "dataclasses",
#                   "version": "0.8",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "debugpy",
#                   "version": "1.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "decorator",
#                   "version": "5.1.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "defusedxml",
#                   "version": "0.7.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "docutils",
#                   "version": "0.17.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "entrypoints",
#                   "version": "0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "eventio",
#                   "version": "1.5.1.post1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "executing",
#                   "version": "0.8.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "flit-core",
#                   "version": "3.6.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "future",
#                   "version": "0.18.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "gammapy",
#                   "version": "0.18.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "h5py",
#                   "version": "3.6.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "hypothesis",
#                   "version": "6.35.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "idna",
#                   "version": "3.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "imagesize",
#                   "version": "1.3.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "iminuit",
#                   "version": "1.5.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "importlib-metadata",
#                   "version": "4.10.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "importlib-resources",
#                   "version": "5.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "iniconfig",
#                   "version": "1.1.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ipykernel",
#                   "version": "6.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ipympl",
#                   "version": "0.8.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ipython",
#                   "version": "8.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ipython-genutils",
#                   "version": "0.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ipywidgets",
#                   "version": "7.6.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jedi",
#                   "version": "0.18.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "joblib",
#                   "version": "1.1.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "json5",
#                   "version": "0.9.6",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jsonschema",
#                   "version": "4.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyter",
#                   "version": "1.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyter-client",
#                   "version": "7.1.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyter-console",
#                   "version": "6.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyter-core",
#                   "version": "4.9.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyter-server",
#                   "version": "1.4.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyterlab",
#                   "version": "3.2.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyterlab-pygments",
#                   "version": "0.1.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyterlab-server",
#                   "version": "2.10.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "jupyterlab-widgets",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "kiwisolver",
#                   "version": "1.3.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "llvmlite",
#                   "version": "0.38.0",
#                   "path": null
#                },
#                {
#                   "name": "lstchain",
#                   "version": "0.8.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "matplotlib",
#                   "version": "3.4.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "matplotlib-inline",
#                   "version": "0.1.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "mistune",
#                   "version": "0.8.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "mock",
#                   "version": "4.0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "mypy-extensions",
#                   "version": "0.4.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "nbclassic",
#                   "version": "0.2.6",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "nbclient",
#                   "version": "0.5.10",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "nbconvert",
#                   "version": "6.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "nbformat",
#                   "version": "5.1.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "nbsphinx",
#                   "version": "0.8.8",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "nest-asyncio",
#                   "version": "1.5.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "notebook",
#                   "version": "6.4.7",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "numba",
#                   "version": "0.55.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "numexpr",
#                   "version": "2.8.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "numpy",
#                   "version": "1.21.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "numpydoc",
#                   "version": "1.1.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "olefile",
#                   "version": "0.46",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "packaging",
#                   "version": "21.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pandas",
#                   "version": "1.3.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pandocfilters",
#                   "version": "1.5.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "parso",
#                   "version": "0.8.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pathspec",
#                   "version": "0.9.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "patsy",
#                   "version": "0.5.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pexpect",
#                   "version": "4.8.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pickleshare",
#                   "version": "0.7.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pip",
#                   "version": "21.3.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "platformdirs",
#                   "version": "2.3.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pluggy",
#                   "version": "1.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "prometheus-client",
#                   "version": "0.12.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "prompt-toolkit",
#                   "version": "3.0.24",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "protobuf",
#                   "version": "3.19.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "protozfits",
#                   "version": "2.0.1.post1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "psutil",
#                   "version": "5.9.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "ptyprocess",
#                   "version": "0.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pure-eval",
#                   "version": "0.2.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "py",
#                   "version": "1.11.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pyOpenSSL",
#                   "version": "21.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pycparser",
#                   "version": "2.21",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pydantic",
#                   "version": "1.9.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pyerfa",
#                   "version": "2.0.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pyirf",
#                   "version": "0.5.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pymongo",
#                   "version": "4.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pyparsing",
#                   "version": "2.4.7",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pyrsistent",
#                   "version": "0.18.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest",
#                   "version": "6.2.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-arraydiff",
#                   "version": "0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-astropy",
#                   "version": "0.9.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-astropy-header",
#                   "version": "0.1.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-cov",
#                   "version": "3.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-doctestplus",
#                   "version": "0.11.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-filter-subpackage",
#                   "version": "0.1.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-mock",
#                   "version": "3.6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-openfiles",
#                   "version": "0.5.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytest-remotedata",
#                   "version": "0.3.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "python-dateutil",
#                   "version": "2.8.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pytz",
#                   "version": "2021.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "pyzmq",
#                   "version": "22.3.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "qtconsole",
#                   "version": "5.2.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "regions",
#                   "version": "0.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "requests",
#                   "version": "2.27.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "scikit-learn",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "scipy",
#                   "version": "1.7.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "seaborn",
#                   "version": "0.11.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "setuptools",
#                   "version": "59.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "setuptools-scm",
#                   "version": "6.3.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "six",
#                   "version": "1.16.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sniffio",
#                   "version": "1.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "snowballstemmer",
#                   "version": "2.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sortedcontainers",
#                   "version": "2.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-argparse",
#                   "version": "0.3.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-automodapi",
#                   "version": "0.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-rtd-theme",
#                   "version": "1.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-applehelp",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-devhelp",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-htmlhelp",
#                   "version": "2.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-jsmath",
#                   "version": "1.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-qthelp",
#                   "version": "1.0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-serializinghtml",
#                   "version": "1.1.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "stack-data",
#                   "version": "0.1.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "statsmodels",
#                   "version": "0.13.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tables",
#                   "version": "3.6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "terminado",
#                   "version": "0.12.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "testpath",
#                   "version": "0.5.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "threadpoolctl",
#                   "version": "3.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "toml",
#                   "version": "0.10.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tomli",
#                   "version": "1.2.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tornado",
#                   "version": "6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tqdm",
#                   "version": "4.62.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "traitlets",
#                   "version": "5.0.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "typed-ast",
#                   "version": "1.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "typing-extensions",
#                   "version": "4.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "urllib3",
#                   "version": "1.26.8",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "wcwidth",
#                   "version": "0.2.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "webencodings",
#                   "version": "0.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "wheel",
#                   "version": "0.37.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "widgetsnbextension",
#                   "version": "3.5.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "zipp",
#                   "version": "3.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "zstandard",
#                   "version": "0.16.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                }
#             ]
#          },
#          "environment": {
#             "CONDA_DEFAULT_ENV": "lst-school-2022-01",
#             "CONDA_PREFIX": "/opt/miniconda3/envs/lst-school-2022-01",
#             "CONDA_PYTHON_EXE": "/opt/miniconda3/bin/python",
#             "CONDA_EXE": "/opt/miniconda3/bin/conda",
#             "CONDA_PROMPT_MODIFIER": "(lst-school-2022-01) ",
#             "CONDA_SHLVL": "2",
#             "PATH": "/Users/jer/.rbenv/shims:/opt/miniconda3/envs/lst-school-2022-01/bin:/opt/miniconda3/condabin:/Users/jer/root/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin:/Library/TeX/texbin:/opt/X11/bin",
#             "LD_LIBRARY_PATH": "/Users/jer/root/lib",
#             "DYLD_LIBRARY_PATH": null,
#             "USER": "jer",
#             "HOME": "/Users/jer",
#             "SHELL": "/bin/zsh"
#          },
#          "arguments": [
#             "/opt/miniconda3/envs/lst-school-2022-01/bin/ctapipe-stage1",
#             "--input",
#             "gamma_test.simtel.gz",
#             "--progress",
#             "--overwrite",
#             "--log-file",
#             "mylog.log"
#          ],
#          "start_time_utc": "2022-01-17T12:46:20.057"
#       },
#       "input": [
#          {
#             "url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#             "role": "DL0/Event"
#          }
#       ],
#       "output": [
#          {
#             "url": "/Users/jer/Desktop/curso/notebooks/events.dl1.h5",
#             "role": "DL1/Event"
#          }
#       ],
#       "config": {
#          "Stage1Tool": {
#             "config_file": null,
#             "log_config": {
#                "version": 1,
#                "disable_existing_loggers": false,
#                "formatters": {
#                   "file": {
#                      "()": null,
#                      "fmt": "%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s"
#                   },
#                   "console": {
#                      "()": null,
#                      "fmt": "%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s"
#                   }
#                },
#                "handlers": {
#                   "ctapipe-console": {
#                      "class": "logging.StreamHandler",
#                      "formatter": "console",
#                      "stream": "ext://sys.stderr",
#                      "level": 30
#                   },
#                   "console": {
#                      "class": "logging.StreamHandler",
#                      "formatter": "console",
#                      "stream": "ext://sys.stderr",
#                      "level": "NOTSET"
#                   },
#                   "ctapipe-file": {
#                      "class": "logging.FileHandler",
#                      "formatter": "file",
#                      "filename": "/Users/jer/Desktop/curso/notebooks/mylog.log",
#                      "level": "INFO"
#                   }
#                },
#                "loggers": {
#                   "ctapipe": {
#                      "level": 20,
#                      "handlers": [
#                         "ctapipe-console",
#                         "ctapipe-file",
#                         "ctapipe-file"
#                      ],
#                      "propagate": false
#                   }
#                }
#             },
#             "log_datefmt": "%Y-%m-%d %H:%M:%S",
#             "log_file": "/Users/jer/Desktop/curso/notebooks/mylog.log",
#             "log_file_level": "INFO",
#             "log_format": "[%(name)s]%(highlevel)s %(message)s",
#             "log_level": 30,
#             "progress_bar": true,
#             "provenance_log": "/Users/jer/Desktop/curso/notebooks/ctapipe-stage1.provenance.log",
#             "quiet": false,
#             "show_config": false,
#             "show_config_json": false,
#             "SimTelEventSource": {
#                "allowed_tels": null,
#                "back_seekable": false,
#                "focal_length_choice": "nominal",
#                "gain_selector_type": "ThresholdGainSelector",
#                "input_url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#                "max_events": null,
#                "skip_calibration_events": true,
#                "ThresholdGainSelector": {
#                   "threshold": 4000.0
#                }
#             },
#             "CameraCalibrator": {
#                "apply_peak_time_shift": [
#                   [
#                      "type",
#                      "*",
#                      true
#                   ]
#                ],
#                "apply_waveform_time_shift": [
#                   [
#                      "type",
#                      "*",
#                      false
#                   ]
#                ],
#                "data_volume_reducer_type": "NullDataVolumeReducer",
#                "image_extractor_type": [
#                   [
#                      "type",
#                      "*",
#                      "NeighborPeakWindowSum"
#                   ]
#                ],
#                "NullDataVolumeReducer": {}
#             },
#             "ImageProcessor": {
#                "image_cleaner_type": "TailcutsImageCleaner",
#                "TailcutsImageCleaner": {
#                   "boundary_threshold_pe": [
#                      [
#                         "type",
#                         "*",
#                         5.0
#                      ]
#                   ],
#                   "keep_isolated_pixels": [
#                      [
#                         "type",
#                         "*",
#                         false
#                      ]
#                   ],
#                   "min_picture_neighbors": [
#                      [
#                         "type",
#                         "*",
#                         2
#                      ]
#                   ],
#                   "picture_threshold_pe": [
#                      [
#                         "type",
#                         "*",
#                         10.0
#                      ]
#                   ]
#                },
#                "ImageQualityQuery": {
#                   "quality_criteria": [
#                      [
#                         "TOTAL",
#                         "lambda x: True"
#                      ],
#                      [
#                         "size_greater_0",
#                         "lambda image_selected: image_selected.sum() > 0"
#                      ]
#                   ]
#                }
#             },
#             "DL1Writer": {
#                "compression_level": 5,
#                "compression_type": "blosc:zstd",
#                "image_dtype": "int32",
#                "image_offset": 0,
#                "image_scale": 10.0,
#                "output_path": "/Users/jer/Desktop/curso/notebooks/events.dl1.h5",
#                "overwrite": true,
#                "peak_time_dtype": "int16",
#                "peak_time_offset": 0,
#                "peak_time_scale": 100.0,
#                "split_datasets_by": "tel_id",
#                "transform_image": false,
#                "transform_peak_time": false,
#                "write_images": false,
#                "write_index_tables": false,
#                "write_parameters": true,
#                "SimTelEventSource": {
#                   "allowed_tels": null,
#                   "back_seekable": false,
#                   "focal_length_choice": "nominal",
#                   "gain_selector_type": "ThresholdGainSelector",
#                   "input_url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#                   "max_events": null,
#                   "skip_calibration_events": true,
#                   "ThresholdGainSelector": {
#                      "threshold": 4000.0
#                   }
#                },
#                "HDF5TableWriter": {}
#             }
#          }
#       },
#       "status": "completed",
#       "duration_min": 0.10381666666656741
#    }
# ][
#    {
#       "activity_name": "ctapipe-stage1",
#       "activity_uuid": "99f18a96-dc2e-47c4-89bd-aa50acaff48a",
#       "start": {
#          "time_utc": "2022-01-17T12:46:30.621"
#       },
#       "stop": {
#          "time_utc": "2022-01-17T12:46:37.331"
#       },
#       "system": {
#          "ctapipe_version": "0.11.0",
#          "ctapipe_resources_version": "not installed",
#          "eventio_version": "1.5.1.post1",
#          "ctapipe_svc_path": "/Users/jer/git/cta-observatory/ctapipe-extra/ctapipe_resources",
#          "executable": "/opt/miniconda3/envs/lst-school-2022-01/bin/python",
#          "platform": {
#             "architecture_bits": "64bit",
#             "architecture_linkage": "",
#             "machine": "x86_64",
#             "processor": "i386",
#             "node": "Joses-MacBook-Pro.local",
#             "version": "Darwin Kernel Version 21.2.0: Sun Nov 28 20:28:54 PST 2021; root:xnu-8019.61.5~1/RELEASE_X86_64",
#             "system": "Darwin",
# ...
#                   "name": "requests",
#                   "version": "2.27.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "scikit-learn",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "scipy",
#                   "version": "1.7.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "seaborn",
#                   "version": "0.11.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "setuptools",
#                   "version": "59.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "setuptools-scm",
#                   "version": "6.3.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "six",
#                   "version": "1.16.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sniffio",
#                   "version": "1.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "snowballstemmer",
#                   "version": "2.2.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sortedcontainers",
#                   "version": "2.4.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-argparse",
#                   "version": "0.3.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-automodapi",
#                   "version": "0.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinx-rtd-theme",
#                   "version": "1.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-applehelp",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-devhelp",
#                   "version": "1.0.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-htmlhelp",
#                   "version": "2.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-jsmath",
#                   "version": "1.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-qthelp",
#                   "version": "1.0.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "sphinxcontrib-serializinghtml",
#                   "version": "1.1.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "stack-data",
#                   "version": "0.1.4",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "statsmodels",
#                   "version": "0.13.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tables",
#                   "version": "3.6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "terminado",
#                   "version": "0.12.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "testpath",
#                   "version": "0.5.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "threadpoolctl",
#                   "version": "3.0.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "toml",
#                   "version": "0.10.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tomli",
#                   "version": "1.2.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tornado",
#                   "version": "6.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "tqdm",
#                   "version": "4.62.3",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "traitlets",
#                   "version": "5.0.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "typed-ast",
#                   "version": "1.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "typing-extensions",
#                   "version": "4.0.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "urllib3",
#                   "version": "1.26.8",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "wcwidth",
#                   "version": "0.2.5",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "webencodings",
#                   "version": "0.5.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "wheel",
#                   "version": "0.37.1",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "widgetsnbextension",
#                   "version": "3.5.2",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "zipp",
#                   "version": "3.7.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                },
#                {
#                   "name": "zstandard",
#                   "version": "0.16.0",
#                   "path": "/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages"
#                }
#             ]
#          },
#          "environment": {
#             "CONDA_DEFAULT_ENV": "lst-school-2022-01",
#             "CONDA_PREFIX": "/opt/miniconda3/envs/lst-school-2022-01",
#             "CONDA_PYTHON_EXE": "/opt/miniconda3/bin/python",
#             "CONDA_EXE": "/opt/miniconda3/bin/conda",
#             "CONDA_PROMPT_MODIFIER": "(lst-school-2022-01) ",
#             "CONDA_SHLVL": "2",
#             "PATH": "/Users/jer/.rbenv/shims:/opt/miniconda3/envs/lst-school-2022-01/bin:/opt/miniconda3/condabin:/Users/jer/root/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin:/Library/TeX/texbin:/opt/X11/bin",
#             "LD_LIBRARY_PATH": "/Users/jer/root/lib",
#             "DYLD_LIBRARY_PATH": null,
#             "USER": "jer",
#             "HOME": "/Users/jer",
#             "SHELL": "/bin/zsh"
#          },
#          "arguments": [
#             "/opt/miniconda3/envs/lst-school-2022-01/bin/ctapipe-stage1",
#             "--input",
#             "gamma_test.simtel.gz",
#             "--progress",
#             "--overwrite",
#             "--log-file",
#             "mylog.log",
#             "--log-level",
#             "DEBUG"
#          ],
#          "start_time_utc": "2022-01-17T12:46:30.644"
#       },
#       "input": [
#          {
#             "url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#             "role": "DL0/Event"
#          }
#       ],
#       "output": [
#          {
#             "url": "/Users/jer/Desktop/curso/notebooks/events.dl1.h5",
#             "role": "DL1/Event"
#          }
#       ],
#       "config": {
#          "Stage1Tool": {
#             "config_file": null,
#             "log_config": {
#                "version": 1,
#                "disable_existing_loggers": false,
#                "formatters": {
#                   "file": {
#                      "()": null,
#                      "fmt": "%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s"
#                   },
#                   "console": {
#                      "()": null,
#                      "fmt": "%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s"
#                   }
#                },
#                "handlers": {
#                   "ctapipe-console": {
#                      "class": "logging.StreamHandler",
#                      "formatter": "console",
#                      "stream": "ext://sys.stderr",
#                      "level": 10
#                   },
#                   "console": {
#                      "class": "logging.StreamHandler",
#                      "formatter": "console",
#                      "stream": "ext://sys.stderr",
#                      "level": "NOTSET"
#                   },
#                   "ctapipe-file": {
#                      "class": "logging.FileHandler",
#                      "formatter": "file",
#                      "filename": "/Users/jer/Desktop/curso/notebooks/mylog.log",
#                      "level": "INFO"
#                   }
#                },
#                "loggers": {
#                   "ctapipe": {
#                      "level": 10,
#                      "handlers": [
#                         "ctapipe-console",
#                         "ctapipe-file",
#                         "ctapipe-file"
#                      ],
#                      "propagate": false
#                   }
#                }
#             },
#             "log_datefmt": "%Y-%m-%d %H:%M:%S",
#             "log_file": "/Users/jer/Desktop/curso/notebooks/mylog.log",
#             "log_file_level": "INFO",
#             "log_format": "[%(name)s]%(highlevel)s %(message)s",
#             "log_level": 10,
#             "progress_bar": true,
#             "provenance_log": "/Users/jer/Desktop/curso/notebooks/ctapipe-stage1.provenance.log",
#             "quiet": false,
#             "show_config": false,
#             "show_config_json": false,
#             "SimTelEventSource": {
#                "allowed_tels": null,
#                "back_seekable": false,
#                "focal_length_choice": "nominal",
#                "gain_selector_type": "ThresholdGainSelector",
#                "input_url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#                "max_events": null,
#                "skip_calibration_events": true,
#                "ThresholdGainSelector": {
#                   "threshold": 4000.0
#                }
#             },
#             "CameraCalibrator": {
#                "apply_peak_time_shift": [
#                   [
#                      "type",
#                      "*",
#                      true
#                   ]
#                ],
#                "apply_waveform_time_shift": [
#                   [
#                      "type",
#                      "*",
#                      false
#                   ]
#                ],
#                "data_volume_reducer_type": "NullDataVolumeReducer",
#                "image_extractor_type": [
#                   [
#                      "type",
#                      "*",
#                      "NeighborPeakWindowSum"
#                   ]
#                ],
#                "NullDataVolumeReducer": {}
#             },
#             "ImageProcessor": {
#                "image_cleaner_type": "TailcutsImageCleaner",
#                "TailcutsImageCleaner": {
#                   "boundary_threshold_pe": [
#                      [
#                         "type",
#                         "*",
#                         5.0
#                      ]
#                   ],
#                   "keep_isolated_pixels": [
#                      [
#                         "type",
#                         "*",
#                         false
#                      ]
#                   ],
#                   "min_picture_neighbors": [
#                      [
#                         "type",
#                         "*",
#                         2
#                      ]
#                   ],
#                   "picture_threshold_pe": [
#                      [
#                         "type",
#                         "*",
#                         10.0
#                      ]
#                   ]
#                },
#                "ImageQualityQuery": {
#                   "quality_criteria": [
#                      [
#                         "TOTAL",
#                         "lambda x: True"
#                      ],
#                      [
#                         "size_greater_0",
#                         "lambda image_selected: image_selected.sum() > 0"
#                      ]
#                   ]
#                }
#             },
#             "DL1Writer": {
#                "compression_level": 5,
#                "compression_type": "blosc:zstd",
#                "image_dtype": "int32",
#                "image_offset": 0,
#                "image_scale": 10.0,
#                "output_path": "/Users/jer/Desktop/curso/notebooks/events.dl1.h5",
#                "overwrite": true,
#                "peak_time_dtype": "int16",
#                "peak_time_offset": 0,
#                "peak_time_scale": 100.0,
#                "split_datasets_by": "tel_id",
#                "transform_image": false,
#                "transform_peak_time": false,
#                "write_images": false,
#                "write_index_tables": false,
#                "write_parameters": true,
#                "SimTelEventSource": {
#                   "allowed_tels": null,
#                   "back_seekable": false,
#                   "focal_length_choice": "nominal",
#                   "gain_selector_type": "ThresholdGainSelector",
#                   "input_url": "/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz",
#                   "max_events": null,
#                   "skip_calibration_events": true,
#                   "ThresholdGainSelector": {
#                      "threshold": 4000.0
#                   }
#                },
#                "HDF5TableWriter": {}
#             }
#          }
#       },
#       "status": "completed",
#       "duration_min": 0.11183333333322665
#    }
# ]

# %% [markdown]
# In order to load the content of this provenance file (concatenaded JSON objects) to a Python list we should proceed in the following way.

# %%
with open('ctapipe-stage1.provenance.log') as json_file:
    rawprov = json_file.read().split('][')
    
prefix = "[\n"
suffix = "\n]"


for i in range(0, len(rawprov)):
    if rawprov[i].startswith(prefix):
        rawprov[i] = rawprov[i][len(prefix):]
    if rawprov[i].endswith(suffix):
        rawprov[i] = rawprov[i][:-len(suffix)]
        
executions = [json.loads(provdata) for provdata in rawprov]

# %%
len(executions)
# Out:
# 2

# %% [markdown]
# Let's see the provenance produced in the second execution of the `ctapipe-stage1` tool

# %%
executions[1]
# Out:
# {'activity_name': 'ctapipe-stage1',
#  'activity_uuid': '99f18a96-dc2e-47c4-89bd-aa50acaff48a',
#  'start': {'time_utc': '2022-01-17T12:46:30.621'},
#  'stop': {'time_utc': '2022-01-17T12:46:37.331'},
#  'system': {'ctapipe_version': '0.11.0',
#   'ctapipe_resources_version': 'not installed',
#   'eventio_version': '1.5.1.post1',
#   'ctapipe_svc_path': '/Users/jer/git/cta-observatory/ctapipe-extra/ctapipe_resources',
#   'executable': '/opt/miniconda3/envs/lst-school-2022-01/bin/python',
#   'platform': {'architecture_bits': '64bit',
#    'architecture_linkage': '',
#    'machine': 'x86_64',
#    'processor': 'i386',
#    'node': 'Joses-MacBook-Pro.local',
#    'version': 'Darwin Kernel Version 21.2.0: Sun Nov 28 20:28:54 PST 2021; root:xnu-8019.61.5~1/RELEASE_X86_64',
#    'system': 'Darwin',
#    'release': '21.2.0',
#    'libcver': ['', ''],
#    'num_cpus': 8,
#    'boot_time': '2021-12-14T21:43:28.000'},
#   'python': {'version_string': '3.8.12 | packaged by conda-forge | (default, Oct 12 2021, 21:50:56) \n[Clang 11.1.0 ]',
#    'version': ['3', '8', '12'],
#    'compiler': 'Clang 11.1.0 ',
#    'implementation': 'CPython',
#    'packages': [{'name': 'Babel',
#      'version': '2.9.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'Jinja2',
#      'version': '3.0.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'MarkupSafe',
#      'version': '2.0.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'Pillow',
#      'version': '8.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'PyQt5',
#      'version': '5.12.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'PyQt5-sip',
#      'version': '4.19.18',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'PyQtChart',
#      'version': '5.12',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'PyQtWebEngine',
#      'version': '5.12.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'PySocks',
#      'version': '1.7.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'PyYAML',
#      'version': '6.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'Pygments',
#      'version': '2.11.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'QtPy',
#      'version': '2.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'Send2Trash',
#      'version': '1.8.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'Sphinx',
#      'version': '4.3.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ViTables',
#      'version': '3.0.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'alabaster',
#      'version': '0.7.12',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'anyio',
#      'version': '2.2.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'appnope',
#      'version': '0.1.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'argon2-cffi',
#      'version': '21.3.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'argon2-cffi-bindings',
#      'version': '21.2.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'astropy',
#      'version': '4.3.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'asttokens',
#      'version': '2.0.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'attrs',
#      'version': '21.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'backcall',
#      'version': '0.2.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'backports.functools-lru-cache',
#      'version': '1.6.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'black',
#      'version': '21.12b0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'bleach',
#      'version': '4.1.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'bokeh',
#      'version': '1.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'brotlipy',
#      'version': '0.7.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'cached-property',
#      'version': '1.5.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'certifi',
#      'version': '2021.10.8',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'cffi',
#      'version': '1.15.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'charset-normalizer',
#      'version': '2.0.10',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'click',
#      'version': '8.0.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'colorama',
#      'version': '0.4.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'commonmark',
#      'version': '0.9.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'corsikaio',
#      'version': '0.2.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'coverage',
#      'version': '6.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'cryptography',
#      'version': '36.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ctapipe',
#      'version': '0.11.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ctapipe-io-lst',
#      'version': '0.13.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ctaplot',
#      'version': '0.5.6',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'cycler',
#      'version': '0.11.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'dataclasses',
#      'version': '0.8',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'debugpy',
#      'version': '1.5.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'decorator',
#      'version': '5.1.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'defusedxml',
#      'version': '0.7.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'docutils',
#      'version': '0.17.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'entrypoints',
#      'version': '0.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'eventio',
#      'version': '1.5.1.post1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'executing',
#      'version': '0.8.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'flit-core',
#      'version': '3.6.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'future',
#      'version': '0.18.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'gammapy',
#      'version': '0.18.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'h5py',
#      'version': '3.6.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'hypothesis',
#      'version': '6.35.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'idna',
#      'version': '3.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'imagesize',
#      'version': '1.3.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'iminuit',
#      'version': '1.5.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'importlib-metadata',
#      'version': '4.10.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'importlib-resources',
#      'version': '5.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'iniconfig',
#      'version': '1.1.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ipykernel',
#      'version': '6.0.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ipympl',
#      'version': '0.8.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ipython',
#      'version': '8.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ipython-genutils',
#      'version': '0.2.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ipywidgets',
#      'version': '7.6.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jedi',
#      'version': '0.18.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'joblib',
#      'version': '1.1.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'json5',
#      'version': '0.9.6',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jsonschema',
#      'version': '4.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyter',
#      'version': '1.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyter-client',
#      'version': '7.1.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyter-console',
#      'version': '6.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyter-core',
#      'version': '4.9.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyter-server',
#      'version': '1.4.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyterlab',
#      'version': '3.2.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyterlab-pygments',
#      'version': '0.1.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyterlab-server',
#      'version': '2.10.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'jupyterlab-widgets',
#      'version': '1.0.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'kiwisolver',
#      'version': '1.3.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'llvmlite', 'version': '0.38.0', 'path': None},
#     {'name': 'lstchain',
#      'version': '0.8.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'matplotlib',
#      'version': '3.4.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'matplotlib-inline',
#      'version': '0.1.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'mistune',
#      'version': '0.8.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'mock',
#      'version': '4.0.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'mypy-extensions',
#      'version': '0.4.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'nbclassic',
#      'version': '0.2.6',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'nbclient',
#      'version': '0.5.10',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'nbconvert',
#      'version': '6.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'nbformat',
#      'version': '5.1.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'nbsphinx',
#      'version': '0.8.8',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'nest-asyncio',
#      'version': '1.5.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'notebook',
#      'version': '6.4.7',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'numba',
#      'version': '0.55.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'numexpr',
#      'version': '2.8.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'numpy',
#      'version': '1.21.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'numpydoc',
#      'version': '1.1.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'olefile',
#      'version': '0.46',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'packaging',
#      'version': '21.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pandas',
#      'version': '1.3.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pandocfilters',
#      'version': '1.5.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'parso',
#      'version': '0.8.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pathspec',
#      'version': '0.9.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'patsy',
#      'version': '0.5.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pexpect',
#      'version': '4.8.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pickleshare',
#      'version': '0.7.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pip',
#      'version': '21.3.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'platformdirs',
#      'version': '2.3.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pluggy',
#      'version': '1.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'prometheus-client',
#      'version': '0.12.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'prompt-toolkit',
#      'version': '3.0.24',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'protobuf',
#      'version': '3.19.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'protozfits',
#      'version': '2.0.1.post1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'psutil',
#      'version': '5.9.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'ptyprocess',
#      'version': '0.7.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pure-eval',
#      'version': '0.2.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'py',
#      'version': '1.11.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pyOpenSSL',
#      'version': '21.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pycparser',
#      'version': '2.21',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pydantic',
#      'version': '1.9.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pyerfa',
#      'version': '2.0.0.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pyirf',
#      'version': '0.5.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pymongo',
#      'version': '4.0.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pyparsing',
#      'version': '2.4.7',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pyrsistent',
#      'version': '0.18.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest',
#      'version': '6.2.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-arraydiff',
#      'version': '0.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-astropy',
#      'version': '0.9.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-astropy-header',
#      'version': '0.1.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-cov',
#      'version': '3.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-doctestplus',
#      'version': '0.11.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-filter-subpackage',
#      'version': '0.1.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-mock',
#      'version': '3.6.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-openfiles',
#      'version': '0.5.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytest-remotedata',
#      'version': '0.3.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'python-dateutil',
#      'version': '2.8.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pytz',
#      'version': '2021.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'pyzmq',
#      'version': '22.3.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'qtconsole',
#      'version': '5.2.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'regions',
#      'version': '0.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'requests',
#      'version': '2.27.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'scikit-learn',
#      'version': '1.0.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'scipy',
#      'version': '1.7.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'seaborn',
#      'version': '0.11.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'setuptools',
#      'version': '59.7.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'setuptools-scm',
#      'version': '6.3.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'six',
#      'version': '1.16.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sniffio',
#      'version': '1.2.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'snowballstemmer',
#      'version': '2.2.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sortedcontainers',
#      'version': '2.4.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinx-argparse',
#      'version': '0.3.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinx-automodapi',
#      'version': '0.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinx-rtd-theme',
#      'version': '1.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-applehelp',
#      'version': '1.0.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-devhelp',
#      'version': '1.0.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-htmlhelp',
#      'version': '2.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-jsmath',
#      'version': '1.0.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-qthelp',
#      'version': '1.0.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-serializinghtml',
#      'version': '1.1.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'stack-data',
#      'version': '0.1.4',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'statsmodels',
#      'version': '0.13.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'tables',
#      'version': '3.6.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'terminado',
#      'version': '0.12.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'testpath',
#      'version': '0.5.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'threadpoolctl',
#      'version': '3.0.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'toml',
#      'version': '0.10.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'tomli',
#      'version': '1.2.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'tornado',
#      'version': '6.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'tqdm',
#      'version': '4.62.3',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'traitlets',
#      'version': '5.0.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'typed-ast',
#      'version': '1.5.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'typing-extensions',
#      'version': '4.0.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'urllib3',
#      'version': '1.26.8',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'wcwidth',
#      'version': '0.2.5',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'webencodings',
#      'version': '0.5.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'wheel',
#      'version': '0.37.1',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'widgetsnbextension',
#      'version': '3.5.2',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'zipp',
#      'version': '3.7.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'},
#     {'name': 'zstandard',
#      'version': '0.16.0',
#      'path': '/opt/miniconda3/envs/lst-school-2022-01/lib/python3.8/site-packages'}]},
#   'environment': {'CONDA_DEFAULT_ENV': 'lst-school-2022-01',
#    'CONDA_PREFIX': '/opt/miniconda3/envs/lst-school-2022-01',
#    'CONDA_PYTHON_EXE': '/opt/miniconda3/bin/python',
#    'CONDA_EXE': '/opt/miniconda3/bin/conda',
#    'CONDA_PROMPT_MODIFIER': '(lst-school-2022-01) ',
#    'CONDA_SHLVL': '2',
#    'PATH': '/Users/jer/.rbenv/shims:/opt/miniconda3/envs/lst-school-2022-01/bin:/opt/miniconda3/condabin:/Users/jer/root/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin:/Library/TeX/texbin:/opt/X11/bin',
#    'LD_LIBRARY_PATH': '/Users/jer/root/lib',
#    'DYLD_LIBRARY_PATH': None,
#    'USER': 'jer',
#    'HOME': '/Users/jer',
#    'SHELL': '/bin/zsh'},
#   'arguments': ['/opt/miniconda3/envs/lst-school-2022-01/bin/ctapipe-stage1',
#    '--input',
#    'gamma_test.simtel.gz',
#    '--progress',
#    '--overwrite',
#    '--log-file',
#    'mylog.log',
#    '--log-level',
#    'DEBUG'],
#   'start_time_utc': '2022-01-17T12:46:30.644'},
#  'input': [{'url': '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz',
#    'role': 'DL0/Event'}],
#  'output': [{'url': '/Users/jer/Desktop/curso/notebooks/events.dl1.h5',
#    'role': 'DL1/Event'}],
#  'config': {'Stage1Tool': {'config_file': None,
#    'log_config': {'version': 1,
#     'disable_existing_loggers': False,
#     'formatters': {'file': {'()': None,
#       'fmt': '%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s'},
#      'console': {'()': None,
#       'fmt': '%(asctime)s %(levelname)s [%(name)s] (%(module)s.%(funcName)s): %(message)s'}},
#     'handlers': {'ctapipe-console': {'class': 'logging.StreamHandler',
#       'formatter': 'console',
#       'stream': 'ext://sys.stderr',
#       'level': 10},
#      'console': {'class': 'logging.StreamHandler',
#       'formatter': 'console',
#       'stream': 'ext://sys.stderr',
#       'level': 'NOTSET'},
#      'ctapipe-file': {'class': 'logging.FileHandler',
#       'formatter': 'file',
#       'filename': '/Users/jer/Desktop/curso/notebooks/mylog.log',
#       'level': 'INFO'}},
#     'loggers': {'ctapipe': {'level': 10,
#       'handlers': ['ctapipe-console', 'ctapipe-file', 'ctapipe-file'],
#       'propagate': False}}},
#    'log_datefmt': '%Y-%m-%d %H:%M:%S',
#    'log_file': '/Users/jer/Desktop/curso/notebooks/mylog.log',
#    'log_file_level': 'INFO',
#    'log_format': '[%(name)s]%(highlevel)s %(message)s',
#    'log_level': 10,
#    'progress_bar': True,
#    'provenance_log': '/Users/jer/Desktop/curso/notebooks/ctapipe-stage1.provenance.log',
#    'quiet': False,
#    'show_config': False,
#    'show_config_json': False,
#    'SimTelEventSource': {'allowed_tels': None,
#     'back_seekable': False,
#     'focal_length_choice': 'nominal',
#     'gain_selector_type': 'ThresholdGainSelector',
#     'input_url': '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz',
#     'max_events': None,
#     'skip_calibration_events': True,
#     'ThresholdGainSelector': {'threshold': 4000.0}},
#    'CameraCalibrator': {'apply_peak_time_shift': [['type', '*', True]],
#     'apply_waveform_time_shift': [['type', '*', False]],
#     'data_volume_reducer_type': 'NullDataVolumeReducer',
#     'image_extractor_type': [['type', '*', 'NeighborPeakWindowSum']],
#     'NullDataVolumeReducer': {}},
#    'ImageProcessor': {'image_cleaner_type': 'TailcutsImageCleaner',
#     'TailcutsImageCleaner': {'boundary_threshold_pe': [['type', '*', 5.0]],
#      'keep_isolated_pixels': [['type', '*', False]],
#      'min_picture_neighbors': [['type', '*', 2]],
#      'picture_threshold_pe': [['type', '*', 10.0]]},
#     'ImageQualityQuery': {'quality_criteria': [['TOTAL', 'lambda x: True'],
#       ['size_greater_0', 'lambda image_selected: image_selected.sum() > 0']]}},
#    'DL1Writer': {'compression_level': 5,
#     'compression_type': 'blosc:zstd',
#     'image_dtype': 'int32',
#     'image_offset': 0,
#     'image_scale': 10.0,
#     'output_path': '/Users/jer/Desktop/curso/notebooks/events.dl1.h5',
#     'overwrite': True,
#     'peak_time_dtype': 'int16',
#     'peak_time_offset': 0,
#     'peak_time_scale': 100.0,
#     'split_datasets_by': 'tel_id',
#     'transform_image': False,
#     'transform_peak_time': False,
#     'write_images': False,
#     'write_index_tables': False,
#     'write_parameters': True,
#     'SimTelEventSource': {'allowed_tels': None,
#      'back_seekable': False,
#      'focal_length_choice': 'nominal',
#      'gain_selector_type': 'ThresholdGainSelector',
#      'input_url': '/Users/jer/Desktop/curso/notebooks/gamma_test.simtel.gz',
#      'max_events': None,
#      'skip_calibration_events': True,
#      'ThresholdGainSelector': {'threshold': 4000.0}},
#     'HDF5TableWriter': {}}}},
#  'status': 'completed',
#  'duration_min': 0.11183333333322665}

# %% [markdown]
# # Exercise

# %% [markdown]
# Once we have the provenance info issued by all the executions of a tool stored into a list of sessions, we could easily access a specific information (i.e. `duration_min`) across all the history of executions and do some porovenance analysis.
